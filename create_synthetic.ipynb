# %%
import os
import shutil
import random
import numpy as np
import pandas as pd

# %% [markdown]
# # Synthetic Dataset Generation
#
# The Synthetic dataset is a dataset that is generated from the FB15k-237 dataset. The dataset is generated to test the performance of the model on a dataset where the model has to understand both the structure and the literal values of the entities. The dataset is generated as follows:

# %%
dataset_name = 'Synthetic'

# should not be modified
literal_relation = '/m/has_value'
relational_relation = '/m/is_a'
class_high = '/m/high'
class_low = '/m/low'

# %%
if 'dataset_name' in os.listdir(f'data/'):
    print('Attention: the directory is not empty. This will overwrite existing files.')
else:
    os.mkdir(f'data/{dataset_name}')
    os.mkdir(f'data/{dataset_name}/literals')
    print('Directories created.')
# Out:
# Directories created.

# %%
# load training file and triple -> class mapping dataframe
train_triples = pd.read_csv('./data/FB15k-237/train.txt', sep='\t', header=None)
class_mapping_df = pd.read_csv('FB15k-237_class_mapping.csv', sep=';', header=0)

# %%
# collect relevant URIs
uris = train_triples[0].unique().tolist() + train_triples[2].unique().tolist()
human_uris = [x for x in class_mapping_df[class_mapping_df["class_label"] == "human"]["dataset_entity"].to_list() if
              x in uris]

# %%
human_uris
# Out:
# ['/m/010hn',
#  '/m/010p3',
#  '/m/010xjr',
#  '/m/0113sg',
#  '/m/011_3s',
#  '/m/011hdn',
#  '/m/011k4g',
#  '/m/011lpr',
#  '/m/011lvx',
#  '/m/011s9r',
#  '/m/011vx3',
#  '/m/011w20',
#  '/m/011xjd',
#  '/m/011zd3',
#  '/m/011zf2',
#  '/m/011zwl',
#  '/m/01200d',
#  '/m/0121rx',
#  '/m/012201',
#  '/m/0126rp',
#  '/m/0126y2',
#  '/m/01271h',
#  '/m/0127gn',
#  '/m/0127m7',
#  '/m/0127s7',
#  '/m/0127xk',
#  '/m/012_53',
#  '/m/012bk',
#  '/m/012c6j',
#  '/m/012c6x',
#  '/m/012cj0',
#  '/m/012cph',
#  '/m/012d40',
#  '/m/012dr7',
#  '/m/012dtf',
#  '/m/012g92',
#  '/m/012gbb',
#  '/m/012gq6',
#  '/m/012gx2',
#  '/m/012j5h',
#  '/m/012j8z',
#  '/m/012ky3',
#  '/m/012ljv',
#  '/m/012pd4',
#  '/m/012q4n',
#  '/m/012rng',
#  '/m/012s5j',
#  '/m/012t1',
#  '/m/012v1t',
#  '/m/012v9y',
#  '/m/012vby',
#  '/m/012vct',
#  '/m/012vd6',
#  '/m/012vf6',
#  '/m/012wg',
#  '/m/012x2b',
#  '/m/012x4t',
#  '/m/012xdf',
#  '/m/012ycy',
#  '/m/012ykt',
#  '/m/012z8_',
#  '/m/012zng',
#  '/m/01304j',
#  '/m/01309x',
#  '/m/0130sy',
#  '/m/0131kb',
#  '/m/0132k4',
#  '/m/01337_',
#  '/m/0133sq',
#  '/m/0133x7',
#  '/m/013423',
#  '/m/0134w7',
#  '/m/0135nb',
#  '/m/0135xb',
#  '/m/01364q',
#  '/m/0136g9',
#  '/m/0136p1',
#  '/m/0136pk',
#  '/m/0137g1',
#  '/m/0137hn',
#  '/m/0137n0',
#  '/m/01385g',
#  '/m/01386_',
#  '/m/0139q5',
#  '/m/013_vh',
#  '/m/013bd1',
#  '/m/013cr',
#  '/m/013km',
#  '/m/013knm',
#  '/m/013pk3',
#  '/m/013pp3',
#  '/m/013qvn',
#  '/m/013rds',
#  '/m/013sg6',
#  '/m/013t9y',
#  '/m/013tcv',
#  '/m/013tjc',
#  '/m/013v5j',
#  '/m/013vdl',
#  '/m/013w7j',
#  '/m/013xrm',
#  '/m/013ybx',
#  '/m/013zs9',
#  '/m/013zyw',
#  '/m/0140t7',
#  '/m/0141kz',
#  '/m/01438g',
#  '/m/0143wl',
#  '/m/014488',
#  '/m/0144l1',
#  '/m/014635',
#  '/m/0146pg',
#  '/m/0147dk',
#  '/m/0147jt',
#  '/m/0149xx',
#  '/m/014cw2',
#  '/m/014dm6',
#  '/m/014dq7',
#  '/m/014g22',
#  '/m/014g91',
#  '/m/014g9y',
#  '/m/014g_s',
#  '/m/014gf8',
#  '/m/014hdb',
#  '/m/014kg4',
#  '/m/014nvr',
#  '/m/014ps4',
#  '/m/014q2g',
#  '/m/014v1q',
#  '/m/014v6f',
#  '/m/014vk4',
#  '/m/014x77',
#  '/m/014y6',
#  '/m/014z8v',
#  '/m/014zcr',
#  '/m/014zfs',
#  '/m/014zn0',
#  '/m/015010',
#  '/m/015076',
#  '/m/01507p',
#  '/m/0150t6',
#  '/m/01515w',
#  '/m/015196',
#  '/m/0151ns',
#  '/m/0151w_',
#  '/m/0151xv',
#  '/m/0151zx',
#  '/m/01520h',
#  '/m/0152cw',
#  '/m/01541z',
#  '/m/0154d7',
#  '/m/0154qm',
#  '/m/0157m',
#  '/m/015882',
#  '/m/0159h6',
#  '/m/015_30',
#  '/m/015c2f',
#  '/m/015c4g',
#  '/m/015cbq',
#  '/m/015d3h',
#  '/m/015dcj',
#  '/m/015dnt',
#  '/m/015dqj',
#  '/m/015f7',
#  '/m/015g_7',
#  '/m/015gjr',
#  '/m/015grj',
#  '/m/015gsv',
#  '/m/015gw6',
#  '/m/015gy7',
#  '/m/015k7',
#  '/m/015lhm',
#  '/m/015mrk',
#  '/m/015n8',
#  '/m/015nhn',
#  '/m/015njf',
#  '/m/015np0',
#  '/m/015npr',
#  '/m/015nvj',
#  '/m/015p37',
#  '/m/015p3p',
#  '/m/015pkc',
#  '/m/015pvh',
#  '/m/015pxr',
#  '/m/015q43',
#  '/m/015qq1',
#  '/m/015qt5',
#  '/m/015qyf',
#  '/m/015rhv',
#  '/m/015rkw',
#  '/m/015rmq',
#  '/m/015t56',
#  '/m/015t7v',
#  '/m/015v3r',
#  '/m/015vq_',
#  '/m/015vql',
#  '/m/015wc0',
#  '/m/015wfg',
#  '/m/015wnl',
#  '/m/015x1f',
#  '/m/015xp4',
#  '/m/015z4j',
#  '/m/015zql',
#  '/m/0161c2',
#  '/m/0161h5',
#  '/m/0161sp',
#  '/m/0162c8',
#  '/m/0163kf',
#  '/m/0163r3',
#  '/m/0163t3',
#  '/m/0164nb',
#  '/m/0164r9',
#  '/m/0164w8',
#  '/m/0164y7',
#  '/m/016732',
#  '/m/0167km',
#  '/m/0167v4',
#  '/m/0168cl',
#  '/m/0168dy',
#  '/m/0168ql',
#  '/m/01693z',
#  '/m/0169dl',
#  '/m/016_mj',
#  '/m/016bx2',
#  '/m/016cff',
#  '/m/016dgz',
#  '/m/016dmx',
#  '/m/016dp0',
#  '/m/016dsy',
#  '/m/016fjj',
#  '/m/016fnb',
#  '/m/016ggh',
#  '/m/016ghw',
#  '/m/016gkf',
#  '/m/016gr2',
#  '/m/016h4r',
#  '/m/016h9b',
#  '/m/016hvl',
#  '/m/016j2t',
#  '/m/016j68',
#  '/m/016jfw',
#  '/m/016jll',
#  '/m/016k62',
#  '/m/016k6x',
#  '/m/016kb7',
#  '/m/016kft',
#  '/m/016khd',
#  '/m/016kjs',
#  '/m/016kkx',
#  '/m/016ks_',
#  '/m/016ksk',
#  '/m/016lh0',
#  '/m/016lv3',
#  '/m/016nff',
#  '/m/016ntp',
#  '/m/016nvh',
#  '/m/016pns',
#  '/m/016qtt',
#  '/m/016s0m',
#  '/m/016s_5',
#  '/m/016sp_',
#  '/m/016sqs',
#  '/m/016srn',
#  '/m/016szr',
#  '/m/016t00',
#  '/m/016tb7',
#  '/m/016tbr',
#  '/m/016vg8',
#  '/m/016vqk',
#  '/m/016wvy',
#  '/m/016xh5',
#  '/m/016xk5',
#  '/m/016ynj',
#  '/m/016ypb',
#  '/m/016yr0',
#  '/m/016yvw',
#  '/m/016ywr',
#  '/m/016yzz',
#  '/m/016z1c',
#  '/m/016z1t',
#  '/m/016z2j',
#  '/m/016z51',
#  '/m/016z68',
#  '/m/016zdd',
#  '/m/016zp5',
#  '/m/0170pk',
#  '/m/0170qf',
#  '/m/0170s4',
#  '/m/0170vn',
#  '/m/01713c',
#  '/m/017149',
#  '/m/0171cm',
#  '/m/0171lb',
#  '/m/0175wg',
#  '/m/0177g',
#  '/m/0177s6',
#  '/m/0178rl',
#  '/m/01797x',
#  '/m/017_pb',
#  '/m/017b2p',
#  '/m/017c87',
#  '/m/017dpj',
#  '/m/017f4y',
#  '/m/017g21',
#  '/m/017g2y',
#  '/m/017gxw',
#  '/m/017khj',
#  '/m/017l4',
#  '/m/017lqp',
#  '/m/017m2y',
#  '/m/017r13',
#  '/m/017r2',
#  '/m/017vkx',
#  '/m/017xm3',
#  '/m/017yfz',
#  '/m/017yxq',
#  '/m/018009',
#  '/m/0180w8',
#  '/m/01817f',
#  '/m/018417',
#  '/m/01846t',
#  '/m/0184dt',
#  '/m/0184jc',
#  '/m/0184jw',
#  '/m/0187y5',
#  '/m/018_lb',
#  '/m/018d6l',
#  '/m/018db8',
#  '/m/018dnt',
#  '/m/018dyl',
#  '/m/018fmr',
#  '/m/018fq',
#  '/m/018fwv',
#  '/m/018gkb',
#  '/m/018gqj',
#  '/m/018grr',
#  '/m/018n6m',
#  '/m/018p4y',
#  '/m/018phr',
#  '/m/018pj3',
#  '/m/018q7',
#  '/m/018qpb',
#  '/m/018qql',
#  '/m/018s6c',
#  '/m/018swb',
#  '/m/018ty9',
#  '/m/018x3',
#  '/m/018y2s',
#  '/m/018y81',
#  '/m/018ygt',
#  '/m/018yj6',
#  '/m/018z_c',
#  '/m/018zvb',
#  '/m/01900g',
#  '/m/0191h5',
#  '/m/01933d',
#  '/m/01934k',
#  '/m/019389',
#  '/m/01938t',
#  '/m/0194xc',
#  '/m/01963w',
#  '/m/0197tq',
#  '/m/019803',
#  '/m/019_1h',
#  '/m/019f2f',
#  '/m/019f9z',
#  '/m/019fnv',
#  '/m/019fz',
#  '/m/019g40',
#  '/m/019g65',
#  '/m/019gz',
#  '/m/019l3m',
#  '/m/019l68',
#  '/m/019lrz',
#  '/m/019n7x',
#  '/m/019pkm',
#  '/m/019pm_',
#  '/m/019r_1',
#  '/m/019vgs',
#  '/m/019x62',
#  '/m/019y64',
#  '/m/019z7q',
#  '/m/01_4z',
#  '/m/01_6dw',
#  '/m/01_f_5',
#  '/m/01_j71',
#  '/m/01_k0d',
#  '/m/01_k1z',
#  '/m/01_k71',
#  '/m/01_njt',
#  '/m/01_p6t',
#  '/m/01_rh4',
#  '/m/01_vfy',
#  '/m/01_x6d',
#  '/m/01_x6v',
#  '/m/01_xtx',
#  '/m/01_ztw',
#  '/m/01b0k1',
#  '/m/01b3bp',
#  '/m/01b9ck',
#  '/m/01b9z4',
#  '/m/01bbwp',
#  '/m/01bcq',
#  '/m/01bczm',
#  '/m/01bh6y',
#  '/m/01bj6y',
#  '/m/01bmlb',
#  '/m/01bpc9',
#  '/m/01bpn',
#  '/m/01bpnd',
#  '/m/01bzr4',
#  '/m/01c1px',
#  '/m/01c58j',
#  '/m/01c59k',
#  '/m/01c5d5',
#  '/m/01c65z',
#  '/m/01c6l',
#  '/m/01c7p_',
#  '/m/01c7qd',
#  '/m/01c8v0',
#  '/m/01cbt3',
#  '/m/01ccr8',
#  '/m/01chc7',
#  '/m/01cj6y',
#  '/m/01ckhj',
#  '/m/01cpqk',
#  '/m/01cqz5',
#  '/m/01cspq',
#  '/m/01csrl',
#  '/m/01csvq',
#  '/m/01cv3n',
#  '/m/01cwcr',
#  '/m/01cwhp',
#  '/m/01cwkq',
#  '/m/01cyjx',
#  '/m/01d0b1',
#  '/m/01d0fp',
#  '/m/01d1st',
#  '/m/01d1yr',
#  '/m/01d494',
#  '/m/01d4cb',
#  '/m/01d5vk',
#  '/m/01d6jf',
#  '/m/01d8yn',
#  '/m/01d_4t',
#  '/m/01d_h',
#  '/m/01dbgw',
#  '/m/01dbhb',
#  '/m/01dbk6',
#  '/m/01dhjz',
#  '/m/01dhmw',
#  '/m/01dhpj',
#  '/m/01dkpb',
#  '/m/01dpsv',
#  '/m/01dvms',
#  '/m/01dvtx',
#  '/m/01dw4q',
#  '/m/01dw9z',
#  '/m/01dw_f',
#  '/m/01dy7j',
#  '/m/01dzz7',
#  '/m/01f2f8',
#  '/m/01f492',
#  '/m/01f5q5',
#  '/m/01f6zc',
#  '/m/01f7dd',
#  '/m/01f7j9',
#  '/m/01f7v_',
#  '/m/01f873',
#  '/m/01f8ld',
#  '/m/01f9mq',
#  '/m/01f9zw',
#  '/m/01fdc0',
#  '/m/01fh0q',
#  '/m/01fh9',
#  '/m/01fkv0',
#  '/m/01fkxr',
#  '/m/01fs_4',
#  '/m/01ft2l',
#  '/m/01fwf1',
#  '/m/01fwj8',
#  '/m/01fwk3',
#  '/m/01fwpt',
#  '/m/01fx2g',
#  '/m/01fx5l',
#  '/m/01fxck',
#  '/m/01fxfk',
#  '/m/01fyzy',
#  '/m/01g04k',
#  '/m/01g0jn',
#  '/m/01g1lp',
#  '/m/01g23m',
#  '/m/01g257',
#  '/m/01g42',
#  '/m/01g4bk',
#  '/m/01g4zr',
#  '/m/01g5kv',
#  '/m/01g6bk',
#  '/m/01g969',
#  '/m/01gbb4',
#  '/m/01gbbz',
#  '/m/01gbn6',
#  '/m/01gc7h',
#  '/m/01gct2',
#  '/m/01gf5h',
#  '/m/01gg59',
#  '/m/01ggbx',
#  '/m/01ggc9',
#  '/m/01gj8_',
#  '/m/01gkmx',
#  '/m/01gn36',
#  '/m/01gp_x',
#  '/m/01gq0b',
#  '/m/01gv_f',
#  '/m/01gvr1',
#  '/m/01gvxv',
#  '/m/01gvyp',
#  '/m/01gw4f',
#  '/m/01gw8b',
#  '/m/01gx5f',
#  '/m/01gy7r',
#  '/m/01gz9n',
#  '/m/01gzm2',
#  '/m/01h1b',
#  '/m/01h2_6',
#  '/m/01h320',
#  '/m/01h4rj',
#  '/m/01h5f8',
#  '/m/01h8f',
#  '/m/01h910',
#  '/m/01hb6v',
#  '/m/01hbgs',
#  '/m/01hbq0',
#  '/m/01hc9_',
#  '/m/01hcj2',
#  '/m/01hdht',
#  '/m/01hgwkr',
#  '/m/01hkck',
#  '/m/01hkg9',
#  '/m/01hkhq',
#  '/m/01hmb_',
#  '/m/01hmk9',
#  '/m/01hrqc',
#  '/m/01htxr',
#  '/m/01hw6wq',
#  '/m/01hxs4',
#  '/m/01j2xj',
#  '/m/01j4ls',
#  '/m/01j590z',
#  '/m/01j5sd',
#  '/m/01j5sv',
#  '/m/01j5ts',
#  '/m/01j5ws',
#  '/m/01j5x6',
#  '/m/01j6mff',
#  '/m/01j7rd',
#  '/m/01j7z7',
#  '/m/01j851',
#  '/m/01jb26',
#  '/m/01jbx1',
#  '/m/01jcjt',
#  '/m/01jfnvd',
#  '/m/01jfr3y',
#  '/m/01jfrg',
#  '/m/01jgkj2',
#  '/m/01jgpsh',
#  '/m/01jllg1',
#  '/m/01jmv8',
#  '/m/01jpmpv',
#  '/m/01jqr_5',
#  '/m/01jrp0',
#  '/m/01jrs46',
#  '/m/01jrvr6',
#  '/m/01jrz5j',
#  '/m/01jw4r',
#  '/m/01jz6d',
#  '/m/01jz6x',
#  '/m/01k165',
#  '/m/01k23t',
#  '/m/01k31p',
#  '/m/01k3qj',
#  '/m/01k47c',
#  '/m/01k53x',
#  '/m/01k56k',
#  '/m/01k5t_3',
#  '/m/01k5zk',
#  '/m/01k6nm',
#  '/m/01k70_',
#  '/m/01k7d9',
#  '/m/01k8rb',
#  '/m/01k98nm',
#  '/m/01k9lpl',
#  '/m/01k_0fp',
#  '/m/01k_mc',
#  '/m/01k_n63',
#  '/m/01k_r5b',
#  '/m/01kb2j',
#  '/m/01kd57',
#  '/m/01kgg9',
#  '/m/01kgv4',
#  '/m/01kgxf',
#  '/m/01kh2m1',
#  '/m/01kj0p',
#  '/m/01kkx2',
#  '/m/01kmd4',
#  '/m/01kp66',
#  '/m/01kp_1t',
#  '/m/01kph_c',
#  '/m/01ksr1',
#  '/m/01kstn9',
#  '/m/01kt17',
#  '/m/01kv4mb',
#  '/m/01kvqc',
#  '/m/01kwh5j',
#  '/m/01kwld',
#  '/m/01kwlwp',
#  '/m/01kws3',
#  '/m/01kwsg',
#  '/m/01kx1j',
#  '/m/01kx_81',
#  '/m/01ky2h',
#  '/m/01kym3',
#  '/m/01kymm',
#  '/m/01l03w2',
#  '/m/01l1b90',
#  '/m/01l1hr',
#  '/m/01l1ls',
#  '/m/01l1rw',
#  '/m/01l1sq',
#  '/m/01l2fn',
#  '/m/01l3j',
#  '/m/01l3mk3',
#  '/m/01l47f5',
#  '/m/01l4g5',
#  '/m/01l4zqz',
#  '/m/01l79yc',
#  '/m/01l7cxq',
#  '/m/01l7qw',
#  '/m/01l87db',
#  '/m/01l9p',
#  '/m/01l9v7n',
#  '/m/01l_vgt',
#  '/m/01l_yg',
#  '/m/01lbp',
#  '/m/01lc5',
#  '/m/01lct6',
#  '/m/01lcxbb',
#  '/m/01ldw4',
#  '/m/01llxp',
#  '/m/01lly5',
#  '/m/01lmj3q',
#  '/m/01lqf49',
#  '/m/01lqnff',
#  '/m/01lvcs1',
#  '/m/01lvzbl',
#  '/m/01lw3kh',
#  '/m/01lwx',
#  '/m/01lz4tf',
#  '/m/01m15br',
#  '/m/01m1dzc',
#  '/m/01m3b1t',
#  '/m/01m3x5p',
#  '/m/01m42d0',
#  '/m/01m4kpp',
#  '/m/01m4yn',
#  '/m/01m5m5b',
#  '/m/01m65sp',
#  '/m/01m7f5r',
#  '/m/01m7pwq',
#  '/m/01mbwlb',
#  '/m/01mh8zn',
#  '/m/01mkn_d',
#  '/m/01mmslz',
#  '/m/01mqc_',
#  '/m/01mqh5',
#  '/m/01mqnr',
#  '/m/01mqz0',
#  '/m/01mr2g6',
#  '/m/01mskc3',
#  '/m/01mt1fy',
#  '/m/01mv_n',
#  '/m/01mvjl0',
#  '/m/01mvpv',
#  '/m/01mvth',
#  '/m/01mwsnc',
#  '/m/01mxnvc',
#  '/m/01mxqyk',
#  '/m/01mxt_',
#  '/m/01my4f',
#  '/m/01my95',
#  '/m/01my_c',
#  '/m/01mylz',
#  '/m/01mz9lt',
#  '/m/01n1gc',
#  '/m/01n44c',
#  '/m/01n4f8',
#  '/m/01n5309',
#  '/m/01n7qlf',
#  '/m/01n8_g',
#  '/m/01n8gr',
#  '/m/01n9d9',
#  '/m/01nbq4',
#  '/m/01nc3rh',
#  '/m/01nczg',
#  '/m/01nd6v',
#  '/m/01nfys',
#  '/m/01nglk',
#  '/m/01nhkxp',
#  '/m/01njxvw',
#  '/m/01nkxvx',
#  '/m/01nm3s',
#  '/m/01nms7',
#  '/m/01nn3m',
#  '/m/01nn6c',
#  '/m/01npcy7',
#  '/m/01nqfh_',
#  '/m/01nr36',
#  '/m/01nr63',
#  '/m/01nrgq',
#  '/m/01nrq5',
#  '/m/01nrz4',
#  '/m/01nsyf',
#  '/m/01nvmd_',
#  '/m/01nwwl',
#  '/m/01nx_8',
#  '/m/01nxzv',
#  '/m/01nz1q6',
#  '/m/01nzz8',
#  '/m/01p0vf',
#  '/m/01p0w_',
#  '/m/01p1z_',
#  '/m/01p45_v',
#  '/m/01p47r',
#  '/m/01p4r3',
#  '/m/01p4vl',
#  '/m/01p6xx',
#  '/m/01p7b6b',
#  '/m/01p7yb',
#  '/m/01p85y',
#  '/m/01p87y',
#  '/m/01p8r8',
#  '/m/01p95y0',
#  '/m/01p9hgt',
#  '/m/01pbs9w',
#  '/m/01pbwwl',
#  '/m/01pbxb',
#  '/m/01pcbg',
#  '/m/01pcdn',
#  '/m/01pcmd',
#  '/m/01pcq3',
#  '/m/01pcql',
#  '/m/01pcrw',
#  '/m/01pctb',
#  '/m/01pcvn',
#  '/m/01pcz9',
#  '/m/01pfkw',
#  '/m/01pg1d',
#  '/m/01pgk0',
#  '/m/01pgzn_',
#  '/m/01phtd',
#  '/m/01pj3h',
#  '/m/01pj5q',
#  '/m/01pjr7',
#  '/m/01pk3z',
#  '/m/01pk8v',
#  '/m/01pkhw',
#  '/m/01pl9g',
#  '/m/01pllx',
#  '/m/01pm0_',
#  '/m/01pnn3',
#  '/m/01pny5',
#  '/m/01pp3p',
#  '/m/01pq5j7',
#  '/m/01pqy_',
#  '/m/01pr6q7',
#  '/m/01pr_j6',
#  '/m/01ps2h8',
#  '/m/01pw2f1',
#  '/m/01pw9v',
#  '/m/01pwz',
#  '/m/01q32bd',
#  '/m/01q3_2',
#  '/m/01q415',
#  '/m/01q4qv',
#  '/m/01q6bg',
#  '/m/01q7cb_',
#  '/m/01q8fxx',
#  '/m/01q8wk7',
#  '/m/01q9b9',
#  '/m/01q_ph',
#  '/m/01q_wyj',
#  '/m/01qbjg',
#  '/m/01qdjm',
#  '/m/01qg7c',
#  '/m/01qgry',
#  '/m/01qklj',
#  '/m/01qkqwg',
#  '/m/01qmy04',
#  '/m/01qn8k',
#  '/m/01qnfc',
#  '/m/01qq_lp',
#  '/m/01qqtr',
#  '/m/01qr1_',
#  '/m/01qrbf',
#  '/m/01qscs',
#  '/m/01qvgl',
#  '/m/01qvtwm',
#  '/m/01qx13',
#  '/m/01qz69r',
#  '/m/01r0t_j',
#  '/m/01r216',
#  '/m/01r2c7',
#  '/m/01r42_g',
#  '/m/01r4bps',
#  '/m/01r4hry',
#  '/m/01r4zfk',
#  '/m/01r6jt2',
#  '/m/01r7pq',
#  '/m/01r7t9',
#  '/m/01r93l',
#  '/m/01r9c_',
#  '/m/01r9fv',
#  '/m/01r9md',
#  '/m/01r_t_',
#  '/m/01rc4p',
#  '/m/01rcmg',
#  '/m/01rddlc',
#  '/m/01rgcg',
#  '/m/01rgr',
#  '/m/01rh0w',
#  '/m/01rlxt',
#  '/m/01rmnp',
#  '/m/01rnpy',
#  '/m/01rnxn',
#  '/m/01rr9f',
#  '/m/01rrd4',
#  '/m/01rrwf6',
#  '/m/01rs5p',
#  '/m/01rw116',
#  '/m/01rwcgb',
#  '/m/01ry0f',
#  '/m/01rzqj',
#  '/m/01rzxl',
#  '/m/01s0l0',
#  '/m/01s1zk',
#  '/m/01s21dg',
#  '/m/01s3kv',
#  '/m/01s7ns',
#  '/m/01s7qqw',
#  '/m/01s7z0',
#  '/m/01s7zw',
#  '/m/01s9ftn',
#  '/m/01sb5r',
#  '/m/01sbf2',
#  '/m/01sbhvd',
#  '/m/01sfmyk',
#  '/m/01sg7_',
#  '/m/01skmp',
#  '/m/01sl1q',
#  '/m/01sp81',
#  '/m/01svw8n',
#  '/m/01swck',
#  '/m/01sxd1',
#  '/m/01sxq9',
#  '/m/01syr4',
#  '/m/01t07j',
#  '/m/01t110',
#  '/m/01t265',
#  '/m/01t2h2',
#  '/m/01t6b4',
#  '/m/01t6xz',
#  '/m/01t8399',
#  '/m/01t94_1',
#  '/m/01t9qj_',
#  '/m/01t_wfl',
#  '/m/01t_z',
#  '/m/01tc9r',
#  '/m/01tcf7',
#  '/m/01tdnyh',
#  '/m/01tfck',
#  '/m/01tj34',
#  '/m/01tkgy',
#  '/m/01tl50z',
#  '/m/01tnbn',
#  '/m/01tnxc',
#  '/m/01tp5bj',
#  '/m/01tpl1p',
#  '/m/01trf3',
#  '/m/01trhmt',
#  '/m/01ts_3',
#  '/m/01tsbmv',
#  '/m/01tspc6',
#  '/m/01tszq',
#  '/m/01tt43d',
#  '/m/01ttg5',
#  '/m/01tv3x2',
#  '/m/01tvz5j',
#  '/m/01tw31',
#  '/m/01twdk',
#  '/m/01twmp',
#  '/m/01ty4',
#  '/m/01ty7ll',
#  '/m/01tz6vs',
#  '/m/01tzm9',
#  '/m/01v0fn1',
#  '/m/01v3bn',
#  '/m/01v3s2_',
#  '/m/01v3vp',
#  '/m/01v40wd',
#  '/m/01v42g',
#  '/m/01v5h',
#  '/m/01v6480',
#  '/m/01v80y',
#  '/m/01v90t',
#  '/m/01v9724',
#  '/m/01v9l67',
#  '/m/01v_0b',
#  '/m/01v_pj6',
#  '/m/01vb403',
#  '/m/01vb6z',
#  '/m/01vd7hn',
#  '/m/01vdrw',
#  '/m/01vh08',
#  '/m/01vh096',
#  '/m/01vh18t',
#  '/m/01vh3r',
#  '/m/01vhb0',
#  '/m/01vhrz',
#  '/m/01vl17',
#  '/m/01vlj1g',
#  '/m/01vn0t_',
#  '/m/01vn35l',
#  '/m/01vng3b',
#  '/m/01vq3nl',
#  '/m/01vqrm',
#  '/m/01vrkdt',
#  '/m/01vrlqd',
#  '/m/01vrlr4',
#  '/m/01vrncs',
#  '/m/01vrnsk',
#  '/m/01vrt_c',
#  '/m/01vrx35',
#  '/m/01vrx3g',
#  '/m/01vrz41',
#  '/m/01vs14j',
#  '/m/01vs4f3',
#  '/m/01vs4ff',
#  '/m/01vs73g',
#  '/m/01vs8ng',
#  '/m/01vs_v8',
#  '/m/01vsgrn',
#  '/m/01vsksr',
#  '/m/01vsl3_',
#  '/m/01vsn38',
#  '/m/01vsnff',
#  '/m/01vsps',
#  '/m/01vsqvs',
#  '/m/01vswwx',
#  '/m/01vswx5',
#  '/m/01vsy3q',
#  '/m/01vsy7t',
#  '/m/01vsy95',
#  '/m/01vsy9_',
#  '/m/01vsyg9',
#  '/m/01vsyjy',
#  '/m/01vsykc',
#  '/m/01vt5c_',
#  '/m/01vt9p3',
#  '/m/01vtg4q',
#  '/m/01vtj38',
#  '/m/01vtmw6',
#  '/m/01vtqml',
#  '/m/01vttb9',
#  '/m/01vv126',
#  '/m/01vv6_6',
#  '/m/01vv6xv',
#  '/m/01vv7sc',
#  '/m/01vvb4m',
#  '/m/01vvdm',
#  '/m/01vvlyt',
#  '/m/01vvpjj',
#  '/m/01vvy',
#  '/m/01vvybv',
#  '/m/01vvyc_',
#  '/m/01vvycq',
#  '/m/01vvyd8',
#  '/m/01vvydl',
#  '/m/01vvyfh',
#  '/m/01vvyvk',
#  '/m/01vvzb1',
#  '/m/01vw20_',
#  '/m/01vw20h',
#  '/m/01vw26l',
#  '/m/01vw37m',
#  '/m/01vw87c',
#  '/m/01vw8mh',
#  '/m/01vw917',
#  '/m/01vw_dv',
#  '/m/01vwbts',
#  '/m/01vwllw',
#  ...]

# %%
# randomly sample literal values for all URIs
uri_to_value = {uri: np.random.rand() for uri in uris}

# %%
# split URIs into train, test, and validation
# this split is just assigns where to add the /m/is_a triples

num_humans = len(human_uris)
random.shuffle(human_uris)

uris_split = {'test': human_uris[:int(num_humans * 0.15)],
              'valid': human_uris[int(num_humans * 0.15):int(num_humans * 0.15) * 2],
              'train': human_uris[int(num_humans * 0.15) * 2:]}

# %%
# create /m/has_value triples and /m/is_a (depending on the sampled values, threshold 0.5) triples for all human entities
attributive_triples = []
relational_triples = {}

for split, uris in uris_split.items():
    relational_triples[split] = []
    for uri in uris:
        relational_triples[split].append(
            (uri, relational_relation, class_high if uri_to_value[uri] > 0.5 else class_low))

for uri, value in uri_to_value.items():
    attributive_triples.append((uri, literal_relation, str(value)))

# %%
#attributive_triples
relational_triples
# Out:
# {'test': [('/m/0frnff', '/m/is_a', '/m/high'),
#   ('/m/02t1cp', '/m/is_a', '/m/low'),
#   ('/m/0d9xq', '/m/is_a', '/m/high'),
#   ('/m/034bs', '/m/is_a', '/m/low'),
#   ('/m/01kph_c', '/m/is_a', '/m/low'),
#   ('/m/065ydwb', '/m/is_a', '/m/high'),
#   ('/m/083chw', '/m/is_a', '/m/low'),
#   ('/m/0djtky', '/m/is_a', '/m/low'),
#   ('/m/0309lm', '/m/is_a', '/m/high'),
#   ('/m/08jtv5', '/m/is_a', '/m/low'),
#   ('/m/02_pft', '/m/is_a', '/m/low'),
#   ('/m/07s3vqk', '/m/is_a', '/m/high'),
#   ('/m/0lk90', '/m/is_a', '/m/high'),
#   ('/m/073w14', '/m/is_a', '/m/low'),
#   ('/m/019fz', '/m/is_a', '/m/high'),
#   ('/m/0840vq', '/m/is_a', '/m/low'),
#   ('/m/01vyp_', '/m/is_a', '/m/low'),
#   ('/m/02qx69', '/m/is_a', '/m/low'),
#   ('/m/03t8v3', '/m/is_a', '/m/high'),
#   ('/m/06y9c2', '/m/is_a', '/m/high'),
#   ('/m/0bqsy', '/m/is_a', '/m/high'),
#   ('/m/03rx9', '/m/is_a', '/m/low'),
#   ('/m/03f1r6t', '/m/is_a', '/m/high'),
#   ('/m/03fqv5', '/m/is_a', '/m/high'),
#   ('/m/053vcrp', '/m/is_a', '/m/low'),
#   ('/m/0kr7k', '/m/is_a', '/m/high'),
#   ('/m/0jrny', '/m/is_a', '/m/high'),
#   ('/m/02p68d', '/m/is_a', '/m/low'),
#   ('/m/03wh8kl', '/m/is_a', '/m/low'),
#   ('/m/02bc74', '/m/is_a', '/m/low'),
#   ('/m/019x62', '/m/is_a', '/m/high'),
#   ('/m/026c1', '/m/is_a', '/m/low'),
#   ('/m/0b7gxq', '/m/is_a', '/m/low'),
#   ('/m/0d500h', '/m/is_a', '/m/high'),
#   ('/m/017g21', '/m/is_a', '/m/high'),
#   ('/m/02q3bb', '/m/is_a', '/m/low'),
#   ('/m/03w4sh', '/m/is_a', '/m/low'),
#   ('/m/0dq2k', '/m/is_a', '/m/high'),
#   ('/m/05xd_v', '/m/is_a', '/m/low'),
#   ('/m/0fqjks', '/m/is_a', '/m/high'),
#   ('/m/01sxq9', '/m/is_a', '/m/low'),
#   ('/m/0d810y', '/m/is_a', '/m/high'),
#   ('/m/02zmh5', '/m/is_a', '/m/high'),
#   ('/m/03h610', '/m/is_a', '/m/high'),
#   ('/m/0m32_', '/m/is_a', '/m/high'),
#   ('/m/01m15br', '/m/is_a', '/m/high'),
#   ('/m/01rrd4', '/m/is_a', '/m/low'),
#   ('/m/0dw3l', '/m/is_a', '/m/high'),
#   ('/m/02t_vx', '/m/is_a', '/m/high'),
#   ('/m/040_t', '/m/is_a', '/m/low'),
#   ('/m/01x53m', '/m/is_a', '/m/low'),
#   ('/m/0341n5', '/m/is_a', '/m/high'),
#   ('/m/037s5h', '/m/is_a', '/m/low'),
#   ('/m/017c87', '/m/is_a', '/m/high'),
#   ('/m/0167km', '/m/is_a', '/m/high'),
#   ('/m/05l0j5', '/m/is_a', '/m/high'),
#   ('/m/0443c', '/m/is_a', '/m/low'),
#   ('/m/09t4hh', '/m/is_a', '/m/high'),
#   ('/m/0rlz', '/m/is_a', '/m/low'),
#   ('/m/02mt4k', '/m/is_a', '/m/low'),
#   ('/m/038rzr', '/m/is_a', '/m/high'),
#   ('/m/01fyzy', '/m/is_a', '/m/high'),
#   ('/m/0lzb8', '/m/is_a', '/m/high'),
#   ('/m/04xjp', '/m/is_a', '/m/high'),
#   ('/m/05z_p6', '/m/is_a', '/m/high'),
#   ('/m/05slvm', '/m/is_a', '/m/high'),
#   ('/m/06lk0_', '/m/is_a', '/m/low'),
#   ('/m/04m_zp', '/m/is_a', '/m/high'),
#   ('/m/0525b', '/m/is_a', '/m/low'),
#   ('/m/05br10', '/m/is_a', '/m/low'),
#   ('/m/030g9z', '/m/is_a', '/m/high'),
#   ('/m/0blpnz', '/m/is_a', '/m/low'),
#   ('/m/01k47c', '/m/is_a', '/m/low'),
#   ('/m/02114t', '/m/is_a', '/m/low'),
#   ('/m/06fmdb', '/m/is_a', '/m/high'),
#   ('/m/02g3w', '/m/is_a', '/m/high'),
#   ('/m/02g75', '/m/is_a', '/m/low'),
#   ('/m/06c0j', '/m/is_a', '/m/low'),
#   ('/m/05w6cw', '/m/is_a', '/m/high'),
#   ('/m/03jht', '/m/is_a', '/m/high'),
#   ('/m/015t56', '/m/is_a', '/m/high'),
#   ('/m/03bxsw', '/m/is_a', '/m/low'),
#   ('/m/058s44', '/m/is_a', '/m/low'),
#   ('/m/0hskw', '/m/is_a', '/m/low'),
#   ('/m/04r7p', '/m/is_a', '/m/low'),
#   ('/m/03kwtb', '/m/is_a', '/m/high'),
#   ('/m/01k7d9', '/m/is_a', '/m/high'),
#   ('/m/04b7xr', '/m/is_a', '/m/high'),
#   ('/m/04s430', '/m/is_a', '/m/high'),
#   ('/m/04jvt', '/m/is_a', '/m/high'),
#   ('/m/0241wg', '/m/is_a', '/m/low'),
#   ('/m/01p9hgt', '/m/is_a', '/m/low'),
#   ('/m/036dyy', '/m/is_a', '/m/high'),
#   ('/m/09p06', '/m/is_a', '/m/high'),
#   ('/m/04r68', '/m/is_a', '/m/high'),
#   ('/m/06mt91', '/m/is_a', '/m/low'),
#   ('/m/01520h', '/m/is_a', '/m/high'),
#   ('/m/01vw87c', '/m/is_a', '/m/high'),
#   ('/m/016kkx', '/m/is_a', '/m/high'),
#   ('/m/01dzz7', '/m/is_a', '/m/low'),
#   ('/m/01yg9y', '/m/is_a', '/m/high'),
#   ('/m/01j5sd', '/m/is_a', '/m/high'),
#   ('/m/0k60', '/m/is_a', '/m/high'),
#   ('/m/0cbdf1', '/m/is_a', '/m/high'),
#   ('/m/026lyl4', '/m/is_a', '/m/high'),
#   ('/m/04hpck', '/m/is_a', '/m/high'),
#   ('/m/01jmv8', '/m/is_a', '/m/high'),
#   ('/m/087_wh', '/m/is_a', '/m/low'),
#   ('/m/03d0ns', '/m/is_a', '/m/high'),
#   ('/m/02cg2v', '/m/is_a', '/m/low'),
#   ('/m/031ydm', '/m/is_a', '/m/low'),
#   ('/m/0gs6vr', '/m/is_a', '/m/low'),
#   ('/m/0bytkq', '/m/is_a', '/m/high'),
#   ('/m/02rn_bj', '/m/is_a', '/m/low'),
#   ('/m/01fwpt', '/m/is_a', '/m/high'),
#   ('/m/02h3tp', '/m/is_a', '/m/high'),
#   ('/m/01gct2', '/m/is_a', '/m/low'),
#   ('/m/066l3y', '/m/is_a', '/m/low'),
#   ('/m/061zc_', '/m/is_a', '/m/low'),
#   ('/m/03xk1_', '/m/is_a', '/m/high'),
#   ('/m/0grrq8', '/m/is_a', '/m/high'),
#   ('/m/06pcz0', '/m/is_a', '/m/high'),
#   ('/m/019_1h', '/m/is_a', '/m/low'),
#   ('/m/03sww', '/m/is_a', '/m/low'),
#   ('/m/01f5q5', '/m/is_a', '/m/high'),
#   ('/m/01pbxb', '/m/is_a', '/m/high'),
#   ('/m/01nd6v', '/m/is_a', '/m/high'),
#   ('/m/03ckxdg', '/m/is_a', '/m/high'),
#   ('/m/043kzcr', '/m/is_a', '/m/low'),
#   ('/m/01k165', '/m/is_a', '/m/high'),
#   ('/m/027lfrs', '/m/is_a', '/m/high'),
#   ('/m/0cdf37', '/m/is_a', '/m/low'),
#   ('/m/05tk7y', '/m/is_a', '/m/high'),
#   ('/m/0m0hw', '/m/is_a', '/m/high'),
#   ('/m/027r8p', '/m/is_a', '/m/high'),
#   ('/m/01tpl1p', '/m/is_a', '/m/low'),
#   ('/m/026sv5l', '/m/is_a', '/m/high'),
#   ('/m/0l9k1', '/m/is_a', '/m/low'),
#   ('/m/01wyz92', '/m/is_a', '/m/low'),
#   ('/m/031x_3', '/m/is_a', '/m/low'),
#   ('/m/054k_8', '/m/is_a', '/m/low'),
#   ('/m/0h953', '/m/is_a', '/m/high'),
#   ('/m/01v42g', '/m/is_a', '/m/high'),
#   ('/m/03nyts', '/m/is_a', '/m/low'),
#   ('/m/0237jb', '/m/is_a', '/m/high'),
#   ('/m/05g3ss', '/m/is_a', '/m/low'),
#   ('/m/0169dl', '/m/is_a', '/m/low'),
#   ('/m/0523v5y', '/m/is_a', '/m/high'),
#   ('/m/01vvycq', '/m/is_a', '/m/high'),
#   ('/m/05nzw6', '/m/is_a', '/m/high'),
#   ('/m/054c1', '/m/is_a', '/m/high'),
#   ('/m/01tcf7', '/m/is_a', '/m/high'),
#   ('/m/0457w0', '/m/is_a', '/m/low'),
#   ('/m/05kwx2', '/m/is_a', '/m/high'),
#   ('/m/03wjb7', '/m/is_a', '/m/low'),
#   ('/m/0bk4s', '/m/is_a', '/m/low'),
#   ('/m/0534nr', '/m/is_a', '/m/high'),
#   ('/m/01f7v_', '/m/is_a', '/m/low'),
#   ('/m/014z8v', '/m/is_a', '/m/low'),
#   ('/m/01p85y', '/m/is_a', '/m/low'),
#   ('/m/05683p', '/m/is_a', '/m/high'),
#   ('/m/01k70_', '/m/is_a', '/m/low'),
#   ('/m/02t1wn', '/m/is_a', '/m/low'),
#   ('/m/033tln', '/m/is_a', '/m/high'),
#   ('/m/01qvtwm', '/m/is_a', '/m/low'),
#   ('/m/02b9g4', '/m/is_a', '/m/low'),
#   ('/m/09889g', '/m/is_a', '/m/low'),
#   ('/m/060pl5', '/m/is_a', '/m/high'),
#   ('/m/0674cw', '/m/is_a', '/m/low'),
#   ('/m/0dvld', '/m/is_a', '/m/low'),
#   ('/m/0l8v5', '/m/is_a', '/m/high'),
#   ('/m/0ftqr', '/m/is_a', '/m/low'),
#   ('/m/02__94', '/m/is_a', '/m/high'),
#   ('/m/04vlh5', '/m/is_a', '/m/high'),
#   ('/m/01b9ck', '/m/is_a', '/m/high'),
#   ('/m/025st2z', '/m/is_a', '/m/high'),
#   ('/m/02wb6d', '/m/is_a', '/m/low'),
#   ('/m/01vvlyt', '/m/is_a', '/m/high'),
#   ('/m/01vw37m', '/m/is_a', '/m/low'),
#   ('/m/039xcr', '/m/is_a', '/m/high'),
#   ('/m/01ww_vs', '/m/is_a', '/m/low'),
#   ('/m/07s95_l', '/m/is_a', '/m/low'),
#   ('/m/02ghq', '/m/is_a', '/m/low'),
#   ('/m/092kgw', '/m/is_a', '/m/low'),
#   ('/m/015qt5', '/m/is_a', '/m/low'),
#   ('/m/02xbw2', '/m/is_a', '/m/high'),
#   ('/m/0cymln', '/m/is_a', '/m/high'),
#   ('/m/01x72k', '/m/is_a', '/m/low'),
#   ('/m/0bc71w', '/m/is_a', '/m/low'),
#   ('/m/02bh9', '/m/is_a', '/m/high'),
#   ('/m/02jg92', '/m/is_a', '/m/high'),
#   ('/m/0gtgp6', '/m/is_a', '/m/low'),
#   ('/m/0g10g', '/m/is_a', '/m/low'),
#   ('/m/09v6tz', '/m/is_a', '/m/low'),
#   ('/m/07nv3_', '/m/is_a', '/m/high'),
#   ('/m/06jkm', '/m/is_a', '/m/high'),
#   ('/m/040j2_', '/m/is_a', '/m/high'),
#   ('/m/09ykwk', '/m/is_a', '/m/low'),
#   ('/m/09f5pp', '/m/is_a', '/m/high'),
#   ('/m/01x6jd', '/m/is_a', '/m/high'),
#   ('/m/012ljv', '/m/is_a', '/m/high'),
#   ('/m/01kwh5j', '/m/is_a', '/m/high'),
#   ('/m/062dn7', '/m/is_a', '/m/low'),
#   ('/m/049468', '/m/is_a', '/m/low'),
#   ('/m/0sw6y', '/m/is_a', '/m/high'),
#   ('/m/08chdb', '/m/is_a', '/m/low'),
#   ('/m/0kbn5', '/m/is_a', '/m/high'),
#   ('/m/01lqf49', '/m/is_a', '/m/low'),
#   ('/m/05b2f_k', '/m/is_a', '/m/high'),
#   ('/m/01wt4wc', '/m/is_a', '/m/high'),
#   ('/m/05jjl', '/m/is_a', '/m/low'),
#   ('/m/03x82v', '/m/is_a', '/m/high'),
#   ('/m/03h_fqv', '/m/is_a', '/m/low'),
#   ('/m/04rg6', '/m/is_a', '/m/low'),
#   ('/m/025p38', '/m/is_a', '/m/high'),
#   ('/m/01vq3nl', '/m/is_a', '/m/low'),
#   ('/m/01w1ywm', '/m/is_a', '/m/high'),
#   ('/m/021vwt', '/m/is_a', '/m/high'),
#   ('/m/044gyq', '/m/is_a', '/m/high'),
#   ('/m/03f70xs', '/m/is_a', '/m/low'),
#   ('/m/0cj2t3', '/m/is_a', '/m/low'),
#   ('/m/01l1sq', '/m/is_a', '/m/high'),
#   ('/m/0282x', '/m/is_a', '/m/high'),
#   ('/m/02wrrm', '/m/is_a', '/m/high'),
#   ('/m/0k57l', '/m/is_a', '/m/low'),
#   ('/m/051y1hd', '/m/is_a', '/m/high'),
#   ('/m/01w_10', '/m/is_a', '/m/low'),
#   ('/m/02w29z', '/m/is_a', '/m/low'),
#   ('/m/06chvn', '/m/is_a', '/m/high'),
#   ('/m/061y4q', '/m/is_a', '/m/high'),
#   ('/m/011lpr', '/m/is_a', '/m/low'),
#   ('/m/058vfp4', '/m/is_a', '/m/low'),
#   ('/m/027cxsm', '/m/is_a', '/m/high'),
#   ('/m/07_grx', '/m/is_a', '/m/low'),
#   ('/m/051ysmf', '/m/is_a', '/m/high'),
#   ('/m/017l4', '/m/is_a', '/m/high'),
#   ('/m/01pgzn_', '/m/is_a', '/m/low'),
#   ('/m/0b05xm', '/m/is_a', '/m/high'),
#   ('/m/032md', '/m/is_a', '/m/low'),
#   ('/m/01y9xg', '/m/is_a', '/m/high'),
#   ('/m/01wrcxr', '/m/is_a', '/m/high'),
#   ('/m/0c1j_', '/m/is_a', '/m/high'),
#   ('/m/02d6cy', '/m/is_a', '/m/high'),
#   ('/m/03xpf_7', '/m/is_a', '/m/low'),
#   ('/m/01r_t_', '/m/is_a', '/m/high'),
#   ('/m/01vh3r', '/m/is_a', '/m/high'),
#   ('/m/05b_7n', '/m/is_a', '/m/high'),
#   ('/m/041b4j', '/m/is_a', '/m/high'),
#   ('/m/0140t7', '/m/is_a', '/m/low'),
#   ('/m/029cpw', '/m/is_a', '/m/low'),
#   ('/m/09d5d5', '/m/is_a', '/m/high'),
#   ('/m/0c8br', '/m/is_a', '/m/low'),
#   ('/m/013tcv', '/m/is_a', '/m/low'),
#   ('/m/026fd', '/m/is_a', '/m/low'),
#   ('/m/01syr4', '/m/is_a', '/m/low'),
#   ('/m/019lrz', '/m/is_a', '/m/low'),
#   ('/m/05th8t', '/m/is_a', '/m/low'),
#   ('/m/015n8', '/m/is_a', '/m/low'),
#   ('/m/013knm', '/m/is_a', '/m/low'),
#   ('/m/03jqw5', '/m/is_a', '/m/high'),
#   ('/m/01lcxbb', '/m/is_a', '/m/low'),
#   ('/m/071jrc', '/m/is_a', '/m/low'),
#   ('/m/05np4c', '/m/is_a', '/m/high'),
#   ('/m/026l37', '/m/is_a', '/m/low'),
#   ('/m/04fhn_', '/m/is_a', '/m/high'),
#   ('/m/01gp_x', '/m/is_a', '/m/high'),
#   ('/m/01pw2f1', '/m/is_a', '/m/high'),
#   ('/m/02lm0t', '/m/is_a', '/m/low'),
#   ('/m/0c9c0', '/m/is_a', '/m/high'),
#   ('/m/0h1p', '/m/is_a', '/m/high'),
#   ('/m/02rmfm', '/m/is_a', '/m/high'),
#   ('/m/03v36', '/m/is_a', '/m/high'),
#   ('/m/08849', '/m/is_a', '/m/high'),
#   ('/m/06rgq', '/m/is_a', '/m/low'),
#   ('/m/02t_w8', '/m/is_a', '/m/low'),
#   ('/m/034g2b', '/m/is_a', '/m/low'),
#   ('/m/0hwbd', '/m/is_a', '/m/low'),
#   ('/m/03p9hl', '/m/is_a', '/m/low'),
#   ('/m/04smkr', '/m/is_a', '/m/low'),
#   ('/m/04j0s3', '/m/is_a', '/m/high'),
#   ('/m/06n7h7', '/m/is_a', '/m/low'),
#   ('/m/06crk', '/m/is_a', '/m/high'),
#   ('/m/06bzwt', '/m/is_a', '/m/low'),
#   ('/m/026rm_y', '/m/is_a', '/m/high'),
#   ('/m/0b_dh', '/m/is_a', '/m/high'),
#   ('/m/043zg', '/m/is_a', '/m/high'),
#   ('/m/01mwsnc', '/m/is_a', '/m/low'),
#   ('/m/03ysmg', '/m/is_a', '/m/high'),
#   ('/m/0fn8jc', '/m/is_a', '/m/high'),
#   ('/m/0brkwj', '/m/is_a', '/m/high'),
#   ('/m/01h320', '/m/is_a', '/m/low'),
#   ('/m/06dn58', '/m/is_a', '/m/high'),
#   ('/m/04353', '/m/is_a', '/m/low'),
#   ('/m/02mx98', '/m/is_a', '/m/low'),
#   ('/m/054bt3', '/m/is_a', '/m/low'),
#   ('/m/02pk6x', '/m/is_a', '/m/low'),
#   ('/m/054_mz', '/m/is_a', '/m/low'),
#   ('/m/0fx02', '/m/is_a', '/m/high'),
#   ('/m/01f7dd', '/m/is_a', '/m/low'),
#   ('/m/022yb4', '/m/is_a', '/m/high'),
#   ('/m/01xpxv', '/m/is_a', '/m/high'),
#   ('/m/04n32', '/m/is_a', '/m/high'),
#   ('/m/030tj5', '/m/is_a', '/m/low'),
#   ('/m/026m0', '/m/is_a', '/m/low'),
#   ('/m/03kts', '/m/is_a', '/m/low'),
#   ('/m/03gr7w', '/m/is_a', '/m/low'),
#   ('/m/028p0', '/m/is_a', '/m/low'),
#   ('/m/03m49ly', '/m/is_a', '/m/low'),
#   ('/m/06449', '/m/is_a', '/m/low'),
#   ('/m/079vf', '/m/is_a', '/m/high'),
#   ('/m/02lfns', '/m/is_a', '/m/high'),
#   ('/m/038nv6', '/m/is_a', '/m/low'),
#   ('/m/016nff', '/m/is_a', '/m/high'),
#   ('/m/02kmx6', '/m/is_a', '/m/high'),
#   ('/m/026b7bz', '/m/is_a', '/m/high'),
#   ('/m/01wgjj5', '/m/is_a', '/m/low'),
#   ('/m/016szr', '/m/is_a', '/m/high'),
#   ('/m/05m7zg', '/m/is_a', '/m/high'),
#   ('/m/015196', '/m/is_a', '/m/low'),
#   ('/m/02my3z', '/m/is_a', '/m/low'),
#   ('/m/06mfvc', '/m/is_a', '/m/high'),
#   ('/m/04m_kpx', '/m/is_a', '/m/low'),
#   ('/m/05d7rk', '/m/is_a', '/m/low'),
#   ('/m/0c5tl', '/m/is_a', '/m/high'),
#   ('/m/05dbyt', '/m/is_a', '/m/low'),
#   ('/m/04ld94', '/m/is_a', '/m/high'),
#   ('/m/047q2wc', '/m/is_a', '/m/high'),
#   ('/m/016dsy', '/m/is_a', '/m/low'),
#   ('/m/01l7qw', '/m/is_a', '/m/low'),
#   ('/m/04g3p5', '/m/is_a', '/m/high'),
#   ('/m/015076', '/m/is_a', '/m/low'),
#   ('/m/02g3mn', '/m/is_a', '/m/low'),
#   ('/m/04zwjd', '/m/is_a', '/m/high'),
#   ('/m/026_w57', '/m/is_a', '/m/low'),
#   ('/m/06b_0', '/m/is_a', '/m/high'),
#   ('/m/01skmp', '/m/is_a', '/m/high'),
#   ('/m/018_lb', '/m/is_a', '/m/high'),
#   ('/m/02r4qs', '/m/is_a', '/m/high'),
#   ('/m/05qg6g', '/m/is_a', '/m/high'),
#   ('/m/0h25', '/m/is_a', '/m/high'),
#   ('/m/01ty4', '/m/is_a', '/m/high'),
#   ('/m/017f4y', '/m/is_a', '/m/low'),
#   ('/m/06w58f', '/m/is_a', '/m/low'),
#   ('/m/03hhd3', '/m/is_a', '/m/high'),
#   ('/m/021r6w', '/m/is_a', '/m/low'),
#   ('/m/0m2wm', '/m/is_a', '/m/high'),
#   ('/m/0d5wn3', '/m/is_a', '/m/low'),
#   ('/m/01vs4f3', '/m/is_a', '/m/low'),
#   ('/m/01kkx2', '/m/is_a', '/m/low'),
#   ('/m/08gwzt', '/m/is_a', '/m/low'),
#   ('/m/0jgwf', '/m/is_a', '/m/high'),
#   ('/m/0f6_x', '/m/is_a', '/m/low'),
#   ('/m/03qkgyl', '/m/is_a', '/m/high'),
#   ('/m/02c0mv', '/m/is_a', '/m/high'),
#   ('/m/05jm7', '/m/is_a', '/m/low'),
#   ('/m/024yxd', '/m/is_a', '/m/low'),
#   ('/m/0dh73w', '/m/is_a', '/m/low'),
#   ('/m/0277c3', '/m/is_a', '/m/high'),
#   ('/m/02hsgn', '/m/is_a', '/m/high'),
#   ('/m/07hyk', '/m/is_a', '/m/low'),
#   ('/m/016kft', '/m/is_a', '/m/low'),
#   ('/m/01vtmw6', '/m/is_a', '/m/low'),
#   ('/m/01vh096', '/m/is_a', '/m/high'),
#   ('/m/0fb7c', '/m/is_a', '/m/low'),
#   ('/m/03gt0c5', '/m/is_a', '/m/low'),
#   ('/m/01vh08', '/m/is_a', '/m/high'),
#   ('/m/0jrg', '/m/is_a', '/m/low'),
#   ('/m/08nz99', '/m/is_a', '/m/high'),
#   ('/m/02l0sf', '/m/is_a', '/m/high'),
#   ('/m/01309x', '/m/is_a', '/m/low'),
#   ('/m/01cwcr', '/m/is_a', '/m/low'),
#   ('/m/0lrh', '/m/is_a', '/m/low'),
#   ('/m/08jfkw', '/m/is_a', '/m/low'),
#   ('/m/01mbwlb', '/m/is_a', '/m/low'),
#   ('/m/020jqv', '/m/is_a', '/m/low'),
#   ('/m/01vqrm', '/m/is_a', '/m/high'),
#   ('/m/04ch23', '/m/is_a', '/m/low'),
#   ('/m/014gf8', '/m/is_a', '/m/high'),
#   ('/m/05vtbl', '/m/is_a', '/m/high'),
#   ('/m/0n00', '/m/is_a', '/m/high'),
#   ('/m/02fcs2', '/m/is_a', '/m/low'),
#   ('/m/01gkmx', '/m/is_a', '/m/low'),
#   ('/m/069d71', '/m/is_a', '/m/low'),
#   ('/m/01k23t', '/m/is_a', '/m/low'),
#   ('/m/037lyl', '/m/is_a', '/m/high'),
#   ('/m/0755wz', '/m/is_a', '/m/high'),
#   ('/m/05hrq4', '/m/is_a', '/m/low'),
#   ('/m/04vcdj', '/m/is_a', '/m/high'),
#   ('/m/03mg35', '/m/is_a', '/m/low'),
#   ('/m/01_vfy', '/m/is_a', '/m/low'),
#   ('/m/06dv3', '/m/is_a', '/m/high'),
#   ('/m/01ydzx', '/m/is_a', '/m/high'),
#   ('/m/0j582', '/m/is_a', '/m/high'),
#   ('/m/0bw6y', '/m/is_a', '/m/high'),
#   ('/m/0f4dx2', '/m/is_a', '/m/high'),
#   ('/m/01bcq', '/m/is_a', '/m/high'),
#   ('/m/016sp_', '/m/is_a', '/m/high'),
#   ('/m/030hcs', '/m/is_a', '/m/high'),
#   ('/m/0f0y8', '/m/is_a', '/m/high'),
#   ('/m/0bw87', '/m/is_a', '/m/high'),
#   ('/m/02lf70', '/m/is_a', '/m/low'),
#   ('/m/0fgg4', '/m/is_a', '/m/low'),
#   ('/m/01846t', '/m/is_a', '/m/high'),
#   ('/m/02z3zp', '/m/is_a', '/m/high'),
#   ('/m/01fh0q', '/m/is_a', '/m/high'),
#   ('/m/01qq_lp', '/m/is_a', '/m/low'),
#   ('/m/012201', '/m/is_a', '/m/high'),
#   ('/m/027y_', '/m/is_a', '/m/low'),
#   ('/m/07q0g5', '/m/is_a', '/m/low'),
#   ('/m/01n5309', '/m/is_a', '/m/high'),
#   ('/m/01t2h2', '/m/is_a', '/m/low'),
#   ('/m/0bs1g5r', '/m/is_a', '/m/low'),
#   ('/m/03f3yfj', '/m/is_a', '/m/low'),
#   ('/m/0gcdzz', '/m/is_a', '/m/low'),
#   ('/m/044rvb', '/m/is_a', '/m/high'),
#   ('/m/02778tk', '/m/is_a', '/m/high'),
#   ('/m/02xs5v', '/m/is_a', '/m/low'),
#   ('/m/050z2', '/m/is_a', '/m/low'),
#   ('/m/047cqr', '/m/is_a', '/m/high'),
#   ('/m/02vxyl5', '/m/is_a', '/m/low'),
#   ('/m/025vry', '/m/is_a', '/m/high'),
#   ('/m/010xjr', '/m/is_a', '/m/high'),
#   ('/m/01y8d4', '/m/is_a', '/m/low'),
#   ('/m/0m_31', '/m/is_a', '/m/low'),
#   ('/m/015gy7', '/m/is_a', '/m/high'),
#   ('/m/01f7j9', '/m/is_a', '/m/high'),
#   ('/m/04mz10g', '/m/is_a', '/m/high'),
#   ('/m/01h910', '/m/is_a', '/m/low'),
#   ('/m/016z51', '/m/is_a', '/m/low'),
#   ('/m/06z9yh', '/m/is_a', '/m/high'),
#   ('/m/02x8z_', '/m/is_a', '/m/low'),
#   ('/m/0227tr', '/m/is_a', '/m/low'),
#   ('/m/01vvpjj', '/m/is_a', '/m/low'),
#   ('/m/07_3qd', '/m/is_a', '/m/high'),
#   ('/m/04pwg', '/m/is_a', '/m/low'),
#   ('/m/067x44', '/m/is_a', '/m/high'),
#   ('/m/032_jg', '/m/is_a', '/m/low'),
#   ('/m/0280mv7', '/m/is_a', '/m/low'),
#   ('/m/025hzx', '/m/is_a', '/m/high'),
#   ('/m/0gqrb', '/m/is_a', '/m/low'),
#   ('/m/06mmb', '/m/is_a', '/m/low'),
#   ('/m/0ff3y', '/m/is_a', '/m/high'),
#   ('/m/0z05l', '/m/is_a', '/m/low'),
#   ('/m/01z0rcq', '/m/is_a', '/m/low'),
#   ('/m/0bv7t', '/m/is_a', '/m/low'),
#   ('/m/03dbds', '/m/is_a', '/m/high'),
#   ('/m/03lt8g', '/m/is_a', '/m/high'),
#   ('/m/09jd9', '/m/is_a', '/m/low'),
#   ('/m/01hdht', '/m/is_a', '/m/high'),
#   ('/m/09byk', '/m/is_a', '/m/high'),
#   ('/m/0b22w', '/m/is_a', '/m/high'),
#   ('/m/023zsh', '/m/is_a', '/m/high'),
#   ('/m/01cj6y', '/m/is_a', '/m/low'),
#   ('/m/03bxh', '/m/is_a', '/m/low'),
#   ('/m/049dyj', '/m/is_a', '/m/low'),
#   ('/m/0b9f7t', '/m/is_a', '/m/low'),
#   ('/m/04qr6d', '/m/is_a', '/m/low'),
#   ('/m/01j4ls', '/m/is_a', '/m/high'),
#   ('/m/0p_jc', '/m/is_a', '/m/high'),
#   ('/m/0pyg6', '/m/is_a', '/m/high'),
#   ('/m/04y8r', '/m/is_a', '/m/high'),
#   ('/m/028mc6', '/m/is_a', '/m/low'),
#   ('/m/06yrj6', '/m/is_a', '/m/high'),
#   ('/m/03nb5v', '/m/is_a', '/m/low'),
#   ('/m/012gbb', '/m/is_a', '/m/low'),
#   ('/m/059xvg', '/m/is_a', '/m/low'),
#   ('/m/027bs_2', '/m/is_a', '/m/low'),
#   ('/m/02cvp8', '/m/is_a', '/m/low'),
#   ('/m/01963w', '/m/is_a', '/m/high'),
#   ('/m/084m3', '/m/is_a', '/m/high'),
#   ('/m/02qdymm', '/m/is_a', '/m/low'),
#   ('/m/0f3zf_', '/m/is_a', '/m/low'),
#   ('/m/05yzt_', '/m/is_a', '/m/high'),
#   ('/m/03pmzt', '/m/is_a', '/m/high'),
#   ('/m/01jfnvd', '/m/is_a', '/m/high'),
#   ('/m/06mn7', '/m/is_a', '/m/high'),
#   ('/m/0f6lx', '/m/is_a', '/m/high'),
#   ('/m/0c00lh', '/m/is_a', '/m/high'),
#   ('/m/0jbyg', '/m/is_a', '/m/high'),
#   ('/m/0h0jz', '/m/is_a', '/m/high'),
#   ('/m/06zmg7m', '/m/is_a', '/m/low'),
#   ('/m/0fd_1', '/m/is_a', '/m/high'),
#   ('/m/042v2', '/m/is_a', '/m/low'),
#   ('/m/015dcj', '/m/is_a', '/m/high'),
#   ('/m/04yj5z', '/m/is_a', '/m/low'),
#   ('/m/0gm8_p', '/m/is_a', '/m/high'),
#   ('/m/01yh3y', '/m/is_a', '/m/high'),
#   ('/m/0fg_hg', '/m/is_a', '/m/low'),
#   ('/m/03gkn5', '/m/is_a', '/m/high'),
#   ('/m/02lf1j', '/m/is_a', '/m/low'),
#   ('/m/05728w1', '/m/is_a', '/m/low'),
#   ('/m/05ry0p', '/m/is_a', '/m/low'),
#   ('/m/04mx__', '/m/is_a', '/m/low'),
#   ('/m/01k5zk', '/m/is_a', '/m/low'),
#   ('/m/049t4g', '/m/is_a', '/m/high'),
#   ('/m/039bp', '/m/is_a', '/m/high'),
#   ('/m/01rs5p', '/m/is_a', '/m/low'),
#   ('/m/026xt5c', '/m/is_a', '/m/low'),
#   ('/m/0mb0', '/m/is_a', '/m/high'),
#   ('/m/03j0d', '/m/is_a', '/m/low'),
#   ('/m/016ntp', '/m/is_a', '/m/high'),
#   ('/m/07r_dg', '/m/is_a', '/m/high'),
#   ('/m/01vw26l', '/m/is_a', '/m/low'),
#   ('/m/01j6mff', '/m/is_a', '/m/low'),
#   ('/m/049tjg', '/m/is_a', '/m/high'),
#   ('/m/04z_x4v', '/m/is_a', '/m/low'),
#   ('/m/01ky2h', '/m/is_a', '/m/high'),
#   ('/m/071xj', '/m/is_a', '/m/low'),
#   ('/m/0k269', '/m/is_a', '/m/high'),
#   ('/m/059t6d', '/m/is_a', '/m/high'),
#   ('/m/06czyr', '/m/is_a', '/m/high'),
#   ('/m/04s5_s', '/m/is_a', '/m/low'),
#   ('/m/07mkj0', '/m/is_a', '/m/low'),
#   ('/m/05mcjs', '/m/is_a', '/m/high'),
#   ('/m/02sjf5', '/m/is_a', '/m/low'),
#   ('/m/06kl0k', '/m/is_a', '/m/high'),
#   ('/m/0bdlj', '/m/is_a', '/m/high'),
#   ('/m/03bdm4', '/m/is_a', '/m/low'),
#   ('/m/01wxyx1', '/m/is_a', '/m/low'),
#   ('/m/02vy5j', '/m/is_a', '/m/low'),
#   ('/m/015dnt', '/m/is_a', '/m/low'),
#   ('/m/091yn0', '/m/is_a', '/m/low'),
#   ('/m/042gr4', '/m/is_a', '/m/low'),
#   ('/m/06101p', '/m/is_a', '/m/low'),
#   ('/m/02q4mt', '/m/is_a', '/m/high'),
#   ('/m/01n4f8', '/m/is_a', '/m/high'),
#   ('/m/0dg3jz', '/m/is_a', '/m/high'),
#   ('/m/01gw8b', '/m/is_a', '/m/low'),
#   ('/m/0cv9fc', '/m/is_a', '/m/low'),
#   ('/m/06bng', '/m/is_a', '/m/high'),
#   ('/m/02qssrm', '/m/is_a', '/m/high'),
#   ('/m/01gf5h', '/m/is_a', '/m/low'),
#   ('/m/0d0l91', '/m/is_a', '/m/high'),
#   ('/m/0139q5', '/m/is_a', '/m/low'),
#   ('/m/0d_84', '/m/is_a', '/m/low'),
#   ('/m/055c8', '/m/is_a', '/m/low'),
#   ('/m/03_l8m', '/m/is_a', '/m/low'),
#   ('/m/06c97', '/m/is_a', '/m/high'),
#   ('/m/0b9l3x', '/m/is_a', '/m/high'),
#   ('/m/02rf51g', '/m/is_a', '/m/low'),
#   ('/m/012dtf', '/m/is_a', '/m/high'),
#   ('/m/0q5hw', '/m/is_a', '/m/low'),
#   ('/m/05ml_s', '/m/is_a', '/m/low'),
#   ('/m/01qkqwg', '/m/is_a', '/m/high'),
#   ('/m/01z5tr', '/m/is_a', '/m/high'),
#   ('/m/01vw917', '/m/is_a', '/m/low'),
#   ('/m/02tn0_', '/m/is_a', '/m/low'),
#   ('/m/08vr94', '/m/is_a', '/m/high'),
#   ('/m/01lw3kh', '/m/is_a', '/m/high'),
#   ('/m/03h502k', '/m/is_a', '/m/high'),
#   ('/m/063vn', '/m/is_a', '/m/high'),
#   ('/m/08_438', '/m/is_a', '/m/low'),
#   ('/m/07v4dm', '/m/is_a', '/m/low'),
#   ('/m/07mz77', '/m/is_a', '/m/low'),
#   ('/m/041_y', '/m/is_a', '/m/low'),
#   ('/m/080knyg', '/m/is_a', '/m/high'),
#   ('/m/0cqcgj', '/m/is_a', '/m/low'),
#   ('/m/04v68c', '/m/is_a', '/m/low'),
#   ('/m/04yt7', '/m/is_a', '/m/low'),
#   ('/m/01ynzf', '/m/is_a', '/m/high'),
#   ('/m/044f7', '/m/is_a', '/m/low'),
#   ('/m/01kp66', '/m/is_a', '/m/high'),
#   ('/m/0x3r3', '/m/is_a', '/m/low'),
#   ('/m/0126rp', '/m/is_a', '/m/low'),
#   ('/m/02773m2', '/m/is_a', '/m/low'),
#   ('/m/0fpjd_g', '/m/is_a', '/m/low'),
#   ('/m/02j3d4', '/m/is_a', '/m/low'),
#   ('/m/02xwq9', '/m/is_a', '/m/high'),
#   ('/m/03xp8d5', '/m/is_a', '/m/high'),
#   ('/m/034q3l', '/m/is_a', '/m/high'),
#   ('/m/06y7d', '/m/is_a', '/m/high'),
#   ('/m/06f_qn', '/m/is_a', '/m/low'),
#   ('/m/02ch1w', '/m/is_a', '/m/low'),
#   ('/m/03s2y9', '/m/is_a', '/m/low'),
#   ('/m/049g_xj', '/m/is_a', '/m/high'),
#   ('/m/0c_mvb', '/m/is_a', '/m/high'),
#   ('/m/03m_k0', '/m/is_a', '/m/high'),
#   ('/m/0163r3', '/m/is_a', '/m/low'),
#   ('/m/044kwr', '/m/is_a', '/m/high'),
#   ('/m/0244r8', '/m/is_a', '/m/low'),
#   ('/m/04sx9_', '/m/is_a', '/m/high'),
#   ('/m/053xw6', '/m/is_a', '/m/high'),
#   ('/m/06j0md', '/m/is_a', '/m/high'),
#   ('/m/06s26c', '/m/is_a', '/m/high'),
#   ('/m/01nx_8', '/m/is_a', '/m/low'),
#   ('/m/08624h', '/m/is_a', '/m/low'),
#   ('/m/02mpb', '/m/is_a', '/m/low'),
#   ('/m/02r5w9', '/m/is_a', '/m/high'),
#   ('/m/01vz0g4', '/m/is_a', '/m/high'),
#   ('/m/04vzv4', '/m/is_a', '/m/low'),
#   ('/m/03qcq', '/m/is_a', '/m/low'),
#   ('/m/012ky3', '/m/is_a', '/m/low'),
#   ('/m/01rgr', '/m/is_a', '/m/high'),
#   ('/m/02l3_5', '/m/is_a', '/m/high'),
#   ('/m/012x4t', '/m/is_a', '/m/high'),
#   ('/m/04g_wd', '/m/is_a', '/m/low'),
#   ('/m/06lbp', '/m/is_a', '/m/high'),
#   ('/m/06jvj7', '/m/is_a', '/m/low'),
#   ('/m/0f_zkz', '/m/is_a', '/m/low'),
#   ('/m/02xwgr', '/m/is_a', '/m/low'),
#   ('/m/01nwwl', '/m/is_a', '/m/high'),
#   ('/m/01_p6t', '/m/is_a', '/m/low'),
#   ('/m/01pm0_', '/m/is_a', '/m/high'),
#   ('/m/01y_px', '/m/is_a', '/m/high'),
#   ('/m/02lkcc', '/m/is_a', '/m/high'),
#   ('/m/09_2gj', '/m/is_a', '/m/low'),
#   ('/m/06czxq', '/m/is_a', '/m/low'),
#   ('/m/01vh18t', '/m/is_a', '/m/low'),
#   ('/m/01j5sv', '/m/is_a', '/m/high'),
#   ('/m/0l6qt', '/m/is_a', '/m/high'),
#   ('/m/01vsnff', '/m/is_a', '/m/low'),
#   ('/m/09r8l', '/m/is_a', '/m/high'),
#   ('/m/022_lg', '/m/is_a', '/m/high'),
#   ('/m/05hj_k', '/m/is_a', '/m/high'),
#   ('/m/01wj18h', '/m/is_a', '/m/low'),
#   ('/m/01pwz', '/m/is_a', '/m/high'),
#   ('/m/020ffd', '/m/is_a', '/m/high'),
#   ('/m/0fn5bx', '/m/is_a', '/m/high'),
#   ('/m/01vrnsk', '/m/is_a', '/m/low'),
#   ('/m/0dbc1s', '/m/is_a', '/m/high'),
#   ('/m/0136g9', '/m/is_a', '/m/high'),
#   ('/m/07vfqj', '/m/is_a', '/m/high'),
#   ('/m/091n7z', '/m/is_a', '/m/high'),
#   ('/m/0hqgp', '/m/is_a', '/m/low'),
#   ('/m/01_njt', '/m/is_a', '/m/low'),
#   ('/m/0cj8x', '/m/is_a', '/m/high'),
#   ('/m/01mxnvc', '/m/is_a', '/m/high'),
#   ('/m/016j68', '/m/is_a', '/m/low'),
#   ('/m/050023', '/m/is_a', '/m/low'),
#   ('/m/02778yp', '/m/is_a', '/m/low'),
#   ('/m/04cbtrw', '/m/is_a', '/m/low'),
#   ('/m/0gt_k', '/m/is_a', '/m/high'),
#   ('/m/02lg9w', '/m/is_a', '/m/high'),
#   ('/m/02_340', '/m/is_a', '/m/low'),
#   ('/m/01vx5w7', '/m/is_a', '/m/high'),
#   ('/m/0ccqd7', '/m/is_a', '/m/low'),
#   ('/m/0dh1n_', '/m/is_a', '/m/high'),
#   ('/m/0bqdvt', '/m/is_a', '/m/high'),
#   ('/m/087qxp', '/m/is_a', '/m/low'),
#   ('/m/07g2b', '/m/is_a', '/m/high'),
#   ('/m/02wd48', '/m/is_a', '/m/high'),
#   ('/m/023322', '/m/is_a', '/m/high'),
#   ('/m/018yj6', '/m/is_a', '/m/high'),
#   ('/m/0356dp', '/m/is_a', '/m/high'),
#   ('/m/03hbzj', '/m/is_a', '/m/high'),
#   ('/m/0h3mrc', '/m/is_a', '/m/high'),
#   ('/m/01vw8mh', '/m/is_a', '/m/high'),
#   ('/m/09dt7', '/m/is_a', '/m/low'),
#   ('/m/0jf1b', '/m/is_a', '/m/low'),
#   ('/m/048q6x', '/m/is_a', '/m/high'),
#   ('/m/02dbp7', '/m/is_a', '/m/high'),
#   ('/m/03n_7k', '/m/is_a', '/m/low'),
#   ('/m/03nbbv', '/m/is_a', '/m/low'),
#   ('/m/09py7', '/m/is_a', '/m/low'),
#   ('/m/073v6', '/m/is_a', '/m/low'),
#   ('/m/07f8wg', '/m/is_a', '/m/high'),
#   ('/m/05_swj', '/m/is_a', '/m/high'),
#   ('/m/0hnjt', '/m/is_a', '/m/high'),
#   ('/m/026lj', '/m/is_a', '/m/high'),
#   ('/m/08vpjv', '/m/is_a', '/m/high'),
#   ('/m/01s9ftn', '/m/is_a', '/m/low'),
#   ('/m/01yfm8', '/m/is_a', '/m/high'),
#   ('/m/01npcy7', '/m/is_a', '/m/high'),
#   ('/m/03s9v', '/m/is_a', '/m/high'),
#   ('/m/03q8ch', '/m/is_a', '/m/low'),
#   ('/m/0272kv', '/m/is_a', '/m/high'),
#   ('/m/016ynj', '/m/is_a', '/m/high'),
#   ('/m/0gjvqm', '/m/is_a', '/m/high'),
#   ('/m/014zn0', '/m/is_a', '/m/high'),
#   ('/m/025t9b', '/m/is_a', '/m/low'),
#   ('/m/011k4g', '/m/is_a', '/m/low'),
#   ('/m/019fnv', '/m/is_a', '/m/high'),
#   ('/m/05p606', '/m/is_a', '/m/low'),
#   ('/m/03k0yw', '/m/is_a', '/m/low'),
#   ('/m/06hgj', '/m/is_a', '/m/low')],
#  'valid': [('/m/024t0y', '/m/is_a', '/m/high'),
#   ('/m/02y8bn', '/m/is_a', '/m/low'),
#   ('/m/02t__3', '/m/is_a', '/m/high'),
#   ('/m/02ctzb', '/m/is_a', '/m/low'),
#   ('/m/01fs_4', '/m/is_a', '/m/high'),
#   ('/m/02t_v1', '/m/is_a', '/m/low'),
#   ('/m/013vdl', '/m/is_a', '/m/low'),
#   ('/m/092ggq', '/m/is_a', '/m/low'),
#   ('/m/05xd8x', '/m/is_a', '/m/low'),
#   ('/m/0427y', '/m/is_a', '/m/low'),
#   ('/m/07lt7b', '/m/is_a', '/m/low'),
#   ('/m/0pkyh', '/m/is_a', '/m/high'),
#   ('/m/0kszw', '/m/is_a', '/m/high'),
#   ('/m/02l6dy', '/m/is_a', '/m/high'),
#   ('/m/01kh2m1', '/m/is_a', '/m/low'),
#   ('/m/02jyhv', '/m/is_a', '/m/low'),
#   ('/m/02s2wq', '/m/is_a', '/m/high'),
#   ('/m/09ntbc', '/m/is_a', '/m/low'),
#   ('/m/0bbxd3', '/m/is_a', '/m/high'),
#   ('/m/09l9xt', '/m/is_a', '/m/low'),
#   ('/m/018gkb', '/m/is_a', '/m/low'),
#   ('/m/02bkdn', '/m/is_a', '/m/low'),
#   ('/m/01vt9p3', '/m/is_a', '/m/high'),
#   ('/m/01l79yc', '/m/is_a', '/m/low'),
#   ('/m/0dzf_', '/m/is_a', '/m/high'),
#   ('/m/02bj6k', '/m/is_a', '/m/high'),
#   ('/m/0g_rs_', '/m/is_a', '/m/high'),
#   ('/m/0lkr7', '/m/is_a', '/m/high'),
#   ('/m/02x08c', '/m/is_a', '/m/low'),
#   ('/m/04m064', '/m/is_a', '/m/high'),
#   ('/m/025j1t', '/m/is_a', '/m/high'),
#   ('/m/015vq_', '/m/is_a', '/m/high'),
#   ('/m/025vw4t', '/m/is_a', '/m/low'),
#   ('/m/07nvmx', '/m/is_a', '/m/low'),
#   ('/m/0jfx1', '/m/is_a', '/m/high'),
#   ('/m/0f830f', '/m/is_a', '/m/high'),
#   ('/m/01vwllw', '/m/is_a', '/m/low'),
#   ('/m/0d06m5', '/m/is_a', '/m/high'),
#   ('/m/05b1062', '/m/is_a', '/m/high'),
#   ('/m/027d5g5', '/m/is_a', '/m/low'),
#   ('/m/02r34n', '/m/is_a', '/m/high'),
#   ('/m/06q8hf', '/m/is_a', '/m/low'),
#   ('/m/06jrhz', '/m/is_a', '/m/high'),
#   ('/m/01vs_v8', '/m/is_a', '/m/high'),
#   ('/m/02y49', '/m/is_a', '/m/high'),
#   ('/m/0c11mj', '/m/is_a', '/m/high'),
#   ('/m/01ts_3', '/m/is_a', '/m/high'),
#   ('/m/016yzz', '/m/is_a', '/m/low'),
#   ('/m/0c_jc', '/m/is_a', '/m/low'),
#   ('/m/01f2f8', '/m/is_a', '/m/high'),
#   ('/m/018n6m', '/m/is_a', '/m/low'),
#   ('/m/01x66d', '/m/is_a', '/m/low'),
#   ('/m/02v0ff', '/m/is_a', '/m/low'),
#   ('/m/01l1b90', '/m/is_a', '/m/high'),
#   ('/m/08mhyd', '/m/is_a', '/m/high'),
#   ('/m/04vt98', '/m/is_a', '/m/low'),
#   ('/m/01bczm', '/m/is_a', '/m/low'),
#   ('/m/03wh8pq', '/m/is_a', '/m/high'),
#   ('/m/01y64_', '/m/is_a', '/m/high'),
#   ('/m/07f7jp', '/m/is_a', '/m/low'),
#   ('/m/03n93', '/m/is_a', '/m/low'),
#   ('/m/01_k0d', '/m/is_a', '/m/high'),
#   ('/m/03q2t9', '/m/is_a', '/m/high'),
#   ('/m/01m4kpp', '/m/is_a', '/m/high'),
#   ('/m/03zz8b', '/m/is_a', '/m/high'),
#   ('/m/0gl88b', '/m/is_a', '/m/high'),
#   ('/m/01ry0f', '/m/is_a', '/m/high'),
#   ('/m/0bxy67', '/m/is_a', '/m/high'),
#   ('/m/0dfrq', '/m/is_a', '/m/low'),
#   ('/m/028qdb', '/m/is_a', '/m/high'),
#   ('/m/094xh', '/m/is_a', '/m/low'),
#   ('/m/0745k7', '/m/is_a', '/m/high'),
#   ('/m/019n7x', '/m/is_a', '/m/low'),
#   ('/m/01m42d0', '/m/is_a', '/m/high'),
#   ('/m/03fwln', '/m/is_a', '/m/high'),
#   ('/m/0c1ps1', '/m/is_a', '/m/low'),
#   ('/m/035kl6', '/m/is_a', '/m/high'),
#   ('/m/01vd7hn', '/m/is_a', '/m/high'),
#   ('/m/0q9vf', '/m/is_a', '/m/high'),
#   ('/m/07_bv_', '/m/is_a', '/m/high'),
#   ('/m/02jtjz', '/m/is_a', '/m/high'),
#   ('/m/0lh0c', '/m/is_a', '/m/low'),
#   ('/m/01gn36', '/m/is_a', '/m/high'),
#   ('/m/030x48', '/m/is_a', '/m/low'),
#   ('/m/023n39', '/m/is_a', '/m/high'),
#   ('/m/04mlh8', '/m/is_a', '/m/low'),
#   ('/m/01gc7h', '/m/is_a', '/m/high'),
#   ('/m/059fjj', '/m/is_a', '/m/high'),
#   ('/m/02_2v2', '/m/is_a', '/m/high'),
#   ('/m/014hdb', '/m/is_a', '/m/high'),
#   ('/m/01l_vgt', '/m/is_a', '/m/high'),
#   ('/m/0g69lg', '/m/is_a', '/m/low'),
#   ('/m/01rrwf6', '/m/is_a', '/m/high'),
#   ('/m/0421st', '/m/is_a', '/m/high'),
#   ('/m/01938t', '/m/is_a', '/m/high'),
#   ('/m/06vqdf', '/m/is_a', '/m/high'),
#   ('/m/01l7cxq', '/m/is_a', '/m/low'),
#   ('/m/06qgjh', '/m/is_a', '/m/high'),
#   ('/m/02l101', '/m/is_a', '/m/high'),
#   ('/m/040nwr', '/m/is_a', '/m/high'),
#   ('/m/0hky', '/m/is_a', '/m/low'),
#   ('/m/01r93l', '/m/is_a', '/m/low'),
#   ('/m/05hjmd', '/m/is_a', '/m/high'),
#   ('/m/01xcr4', '/m/is_a', '/m/high'),
#   ('/m/08304', '/m/is_a', '/m/low'),
#   ('/m/0784v1', '/m/is_a', '/m/low'),
#   ('/m/014g9y', '/m/is_a', '/m/high'),
#   ('/m/02jxmr', '/m/is_a', '/m/high'),
#   ('/m/02wr6r', '/m/is_a', '/m/high'),
#   ('/m/08wjf4', '/m/is_a', '/m/low'),
#   ('/m/017yfz', '/m/is_a', '/m/high'),
#   ('/m/01nrgq', '/m/is_a', '/m/high'),
#   ('/m/02sh8y', '/m/is_a', '/m/high'),
#   ('/m/01tkgy', '/m/is_a', '/m/high'),
#   ('/m/01vsy7t', '/m/is_a', '/m/high'),
#   ('/m/01xg_w', '/m/is_a', '/m/high'),
#   ('/m/053j4w4', '/m/is_a', '/m/high'),
#   ('/m/02hy5d', '/m/is_a', '/m/low'),
#   ('/m/024dw0', '/m/is_a', '/m/high'),
#   ('/m/0j1yf', '/m/is_a', '/m/low'),
#   ('/m/01jgkj2', '/m/is_a', '/m/low'),
#   ('/m/0b455l', '/m/is_a', '/m/high'),
#   ('/m/0fw2d3', '/m/is_a', '/m/low'),
#   ('/m/0814k3', '/m/is_a', '/m/high'),
#   ('/m/037q1z', '/m/is_a', '/m/low'),
#   ('/m/027zz', '/m/is_a', '/m/high'),
#   ('/m/02p59ry', '/m/is_a', '/m/low'),
#   ('/m/030s5g', '/m/is_a', '/m/high'),
#   ('/m/09bxq9', '/m/is_a', '/m/low'),
#   ('/m/07zhd7', '/m/is_a', '/m/low'),
#   ('/m/013zyw', '/m/is_a', '/m/low'),
#   ('/m/01713c', '/m/is_a', '/m/high'),
#   ('/m/05_6_y', '/m/is_a', '/m/low'),
#   ('/m/041rhq', '/m/is_a', '/m/low'),
#   ('/m/02x7vq', '/m/is_a', '/m/low'),
#   ('/m/027_sn', '/m/is_a', '/m/high'),
#   ('/m/0d608', '/m/is_a', '/m/low'),
#   ('/m/04258w', '/m/is_a', '/m/high'),
#   ('/m/03f1zdw', '/m/is_a', '/m/low'),
#   ('/m/09j028', '/m/is_a', '/m/low'),
#   ('/m/01qvgl', '/m/is_a', '/m/high'),
#   ('/m/04vmqg', '/m/is_a', '/m/low'),
#   ('/m/050zr4', '/m/is_a', '/m/low'),
#   ('/m/02jm0n', '/m/is_a', '/m/low'),
#   ('/m/019f9z', '/m/is_a', '/m/low'),
#   ('/m/03v3xp', '/m/is_a', '/m/high'),
#   ('/m/06j8q_', '/m/is_a', '/m/low'),
#   ('/m/01xyt7', '/m/is_a', '/m/low'),
#   ('/m/03x31g', '/m/is_a', '/m/low'),
#   ('/m/06l6nj', '/m/is_a', '/m/high'),
#   ('/m/01vvydl', '/m/is_a', '/m/high'),
#   ('/m/087yty', '/m/is_a', '/m/high'),
#   ('/m/06lht1', '/m/is_a', '/m/low'),
#   ('/m/044mrh', '/m/is_a', '/m/high'),
#   ('/m/03h4mp', '/m/is_a', '/m/low'),
#   ('/m/049sb', '/m/is_a', '/m/high'),
#   ('/m/06cl2w', '/m/is_a', '/m/high'),
#   ('/m/04lg6', '/m/is_a', '/m/high'),
#   ('/m/02bwc7', '/m/is_a', '/m/high'),
#   ('/m/012zng', '/m/is_a', '/m/high'),
#   ('/m/051m56', '/m/is_a', '/m/low'),
#   ('/m/02_33l', '/m/is_a', '/m/low'),
#   ('/m/012gq6', '/m/is_a', '/m/high'),
#   ('/m/01s7ns', '/m/is_a', '/m/low'),
#   ('/m/03hzl42', '/m/is_a', '/m/high'),
#   ('/m/0g9zcgx', '/m/is_a', '/m/high'),
#   ('/m/01pcz9', '/m/is_a', '/m/low'),
#   ('/m/023nlj', '/m/is_a', '/m/low'),
#   ('/m/01q415', '/m/is_a', '/m/high'),
#   ('/m/03jg5t', '/m/is_a', '/m/high'),
#   ('/m/03xpfzg', '/m/is_a', '/m/high'),
#   ('/m/02zyq6', '/m/is_a', '/m/high'),
#   ('/m/0372p', '/m/is_a', '/m/low'),
#   ('/m/012xdf', '/m/is_a', '/m/low'),
#   ('/m/041xl', '/m/is_a', '/m/high'),
#   ('/m/09px1w', '/m/is_a', '/m/low'),
#   ('/m/03mstc', '/m/is_a', '/m/high'),
#   ('/m/0288crq', '/m/is_a', '/m/high'),
#   ('/m/0kbg6', '/m/is_a', '/m/low'),
#   ('/m/04xm_', '/m/is_a', '/m/low'),
#   ('/m/0gpmp', '/m/is_a', '/m/low'),
#   ('/m/01vsps', '/m/is_a', '/m/high'),
#   ('/m/01v_0b', '/m/is_a', '/m/low'),
#   ('/m/01c1px', '/m/is_a', '/m/high'),
#   ('/m/05zrx3v', '/m/is_a', '/m/high'),
#   ('/m/04zd4m', '/m/is_a', '/m/high'),
#   ('/m/04f9r2', '/m/is_a', '/m/high'),
#   ('/m/07sgfsl', '/m/is_a', '/m/high'),
#   ('/m/03f5spx', '/m/is_a', '/m/low'),
#   ('/m/01t_z', '/m/is_a', '/m/low'),
#   ('/m/03rwng', '/m/is_a', '/m/low'),
#   ('/m/01vrkdt', '/m/is_a', '/m/low'),
#   ('/m/01nm3s', '/m/is_a', '/m/high'),
#   ('/m/05zjx', '/m/is_a', '/m/high'),
#   ('/m/06f5j', '/m/is_a', '/m/low'),
#   ('/m/01qklj', '/m/is_a', '/m/low'),
#   ('/m/02665kn', '/m/is_a', '/m/high'),
#   ('/m/01mxt_', '/m/is_a', '/m/high'),
#   ('/m/0141kz', '/m/is_a', '/m/high'),
#   ('/m/01pr6q7', '/m/is_a', '/m/high'),
#   ('/m/015njf', '/m/is_a', '/m/low'),
#   ('/m/03g5_y', '/m/is_a', '/m/low'),
#   ('/m/02_n5d', '/m/is_a', '/m/low'),
#   ('/m/03cdg', '/m/is_a', '/m/high'),
#   ('/m/01wbg84', '/m/is_a', '/m/high'),
#   ('/m/02s6sh', '/m/is_a', '/m/high'),
#   ('/m/02lj6p', '/m/is_a', '/m/high'),
#   ('/m/02lk95', '/m/is_a', '/m/low'),
#   ('/m/01f9mq', '/m/is_a', '/m/high'),
#   ('/m/05sdxx', '/m/is_a', '/m/low'),
#   ('/m/03y2kr', '/m/is_a', '/m/high'),
#   ('/m/08b0cj', '/m/is_a', '/m/high'),
#   ('/m/049qx', '/m/is_a', '/m/low'),
#   ('/m/04q5zw', '/m/is_a', '/m/high'),
#   ('/m/02hkvw', '/m/is_a', '/m/low'),
#   ('/m/0f0qfz', '/m/is_a', '/m/high'),
#   ('/m/059xnf', '/m/is_a', '/m/low'),
#   ('/m/02ck7w', '/m/is_a', '/m/low'),
#   ('/m/034zc0', '/m/is_a', '/m/high'),
#   ('/m/01vsyg9', '/m/is_a', '/m/low'),
#   ('/m/01trf3', '/m/is_a', '/m/high'),
#   ('/m/062ftr', '/m/is_a', '/m/high'),
#   ('/m/02lgj6', '/m/is_a', '/m/high'),
#   ('/m/02fn5', '/m/is_a', '/m/high'),
#   ('/m/0335fp', '/m/is_a', '/m/high'),
#   ('/m/0f0p0', '/m/is_a', '/m/high'),
#   ('/m/026kmvf', '/m/is_a', '/m/low'),
#   ('/m/0466k4', '/m/is_a', '/m/high'),
#   ('/m/06mnps', '/m/is_a', '/m/low'),
#   ('/m/01kgg9', '/m/is_a', '/m/high'),
#   ('/m/0lsw9', '/m/is_a', '/m/low'),
#   ('/m/0739z6', '/m/is_a', '/m/high'),
#   ('/m/03wbzp', '/m/is_a', '/m/high'),
#   ('/m/02xc1w4', '/m/is_a', '/m/low'),
#   ('/m/056rgc', '/m/is_a', '/m/low'),
#   ('/m/0j6cj', '/m/is_a', '/m/low'),
#   ('/m/06lhbl', '/m/is_a', '/m/high'),
#   ('/m/01z7_f', '/m/is_a', '/m/high'),
#   ('/m/03yk8z', '/m/is_a', '/m/low'),
#   ('/m/04nw9', '/m/is_a', '/m/high'),
#   ('/m/016s0m', '/m/is_a', '/m/low'),
#   ('/m/0175wg', '/m/is_a', '/m/low'),
#   ('/m/01vs4ff', '/m/is_a', '/m/low'),
#   ('/m/012z8_', '/m/is_a', '/m/high'),
#   ('/m/02mxbd', '/m/is_a', '/m/low'),
#   ('/m/09lhln', '/m/is_a', '/m/high'),
#   ('/m/01kx1j', '/m/is_a', '/m/low'),
#   ('/m/021lby', '/m/is_a', '/m/high'),
#   ('/m/02tk74', '/m/is_a', '/m/high'),
#   ('/m/01tj34', '/m/is_a', '/m/low'),
#   ('/m/01pk3z', '/m/is_a', '/m/low'),
#   ('/m/0p9gg', '/m/is_a', '/m/high'),
#   ('/m/01kwsg', '/m/is_a', '/m/low'),
#   ('/m/05cx7x', '/m/is_a', '/m/low'),
#   ('/m/01g5kv', '/m/is_a', '/m/high'),
#   ('/m/027km64', '/m/is_a', '/m/high'),
#   ('/m/040696', '/m/is_a', '/m/low'),
#   ('/m/05strv', '/m/is_a', '/m/low'),
#   ('/m/020l9r', '/m/is_a', '/m/low'),
#   ('/m/022wxh', '/m/is_a', '/m/high'),
#   ('/m/01sxd1', '/m/is_a', '/m/high'),
#   ('/m/0415mzy', '/m/is_a', '/m/high'),
#   ('/m/087z12', '/m/is_a', '/m/high'),
#   ('/m/04ns3gy', '/m/is_a', '/m/low'),
#   ('/m/06hzsx', '/m/is_a', '/m/low'),
#   ('/m/01r6jt2', '/m/is_a', '/m/high'),
#   ('/m/0219q', '/m/is_a', '/m/high'),
#   ('/m/03j24kf', '/m/is_a', '/m/high'),
#   ('/m/04s04', '/m/is_a', '/m/high'),
#   ('/m/019pm_', '/m/is_a', '/m/low'),
#   ('/m/0xsk8', '/m/is_a', '/m/low'),
#   ('/m/03j367r', '/m/is_a', '/m/high'),
#   ('/m/01r7pq', '/m/is_a', '/m/low'),
#   ('/m/03lpd0', '/m/is_a', '/m/high'),
#   ('/m/0342vg', '/m/is_a', '/m/high'),
#   ('/m/01w9mnm', '/m/is_a', '/m/high'),
#   ('/m/02vkvcz', '/m/is_a', '/m/low'),
#   ('/m/05v954', '/m/is_a', '/m/high'),
#   ('/m/0459z', '/m/is_a', '/m/low'),
#   ('/m/044n3h', '/m/is_a', '/m/low'),
#   ('/m/0jrqq', '/m/is_a', '/m/high'),
#   ('/m/04bs3j', '/m/is_a', '/m/high'),
#   ('/m/01qmy04', '/m/is_a', '/m/high'),
#   ('/m/06fc0b', '/m/is_a', '/m/low'),
#   ('/m/0dbb3', '/m/is_a', '/m/low'),
#   ('/m/03w9sgh', '/m/is_a', '/m/low'),
#   ('/m/011zd3', '/m/is_a', '/m/low'),
#   ('/m/0m68w', '/m/is_a', '/m/high'),
#   ('/m/0bbf1f', '/m/is_a', '/m/high'),
#   ('/m/030pr', '/m/is_a', '/m/low'),
#   ('/m/01w23w', '/m/is_a', '/m/high'),
#   ('/m/014x77', '/m/is_a', '/m/high'),
#   ('/m/015c4g', '/m/is_a', '/m/high'),
#   ('/m/0275_pj', '/m/is_a', '/m/high'),
#   ('/m/01n8_g', '/m/is_a', '/m/high'),
#   ('/m/05m0h', '/m/is_a', '/m/high'),
#   ('/m/05gp3x', '/m/is_a', '/m/high'),
#   ('/m/06qgvf', '/m/is_a', '/m/low'),
#   ('/m/0gv07g', '/m/is_a', '/m/low'),
#   ('/m/01twmp', '/m/is_a', '/m/high'),
#   ('/m/03xgm3', '/m/is_a', '/m/low'),
#   ('/m/05nqq3', '/m/is_a', '/m/low'),
#   ('/m/02xfrd', '/m/is_a', '/m/high'),
#   ('/m/0154qm', '/m/is_a', '/m/high'),
#   ('/m/0jnb0', '/m/is_a', '/m/low'),
#   ('/m/0gm34', '/m/is_a', '/m/low'),
#   ('/m/08yx9q', '/m/is_a', '/m/low'),
#   ('/m/016fnb', '/m/is_a', '/m/high'),
#   ('/m/048cl', '/m/is_a', '/m/low'),
#   ('/m/0hpz8', '/m/is_a', '/m/high'),
#   ('/m/01p45_v', '/m/is_a', '/m/high'),
#   ('/m/025ldg', '/m/is_a', '/m/low'),
#   ('/m/05xpv', '/m/is_a', '/m/low'),
#   ('/m/0gnbw', '/m/is_a', '/m/high'),
#   ('/m/03qhyn8', '/m/is_a', '/m/low'),
#   ('/m/024jwt', '/m/is_a', '/m/high'),
#   ('/m/0k6yt1', '/m/is_a', '/m/high'),
#   ('/m/017m2y', '/m/is_a', '/m/low'),
#   ('/m/02cx72', '/m/is_a', '/m/low'),
#   ('/m/042kg', '/m/is_a', '/m/low'),
#   ('/m/075p0r', '/m/is_a', '/m/high'),
#   ('/m/07zl1', '/m/is_a', '/m/high'),
#   ('/m/027jq2', '/m/is_a', '/m/low'),
#   ('/m/01tc9r', '/m/is_a', '/m/high'),
#   ('/m/032t2z', '/m/is_a', '/m/low'),
#   ('/m/02vyw', '/m/is_a', '/m/low'),
#   ('/m/07djnx', '/m/is_a', '/m/low'),
#   ('/m/016wvy', '/m/is_a', '/m/high'),
#   ('/m/09fb5', '/m/is_a', '/m/low'),
#   ('/m/046lt', '/m/is_a', '/m/high'),
#   ('/m/023361', '/m/is_a', '/m/high'),
#   ('/m/0bg539', '/m/is_a', '/m/high'),
#   ('/m/01l9p', '/m/is_a', '/m/high'),
#   ('/m/0cf2h', '/m/is_a', '/m/low'),
#   ('/m/014q2g', '/m/is_a', '/m/low'),
#   ('/m/01l4zqz', '/m/is_a', '/m/high'),
#   ('/m/07t2k', '/m/is_a', '/m/low'),
#   ('/m/06nz46', '/m/is_a', '/m/low'),
#   ('/m/04pg29', '/m/is_a', '/m/low'),
#   ('/m/031zkw', '/m/is_a', '/m/high'),
#   ('/m/03j0br4', '/m/is_a', '/m/low'),
#   ('/m/01vtj38', '/m/is_a', '/m/low'),
#   ('/m/0bq4j6', '/m/is_a', '/m/high'),
#   ('/m/0czkbt', '/m/is_a', '/m/high'),
#   ('/m/0392kz', '/m/is_a', '/m/high'),
#   ('/m/03swmf', '/m/is_a', '/m/low'),
#   ('/m/04wp3s', '/m/is_a', '/m/high'),
#   ('/m/089kpp', '/m/is_a', '/m/high'),
#   ('/m/0277990', '/m/is_a', '/m/low'),
#   ('/m/0cb1ky', '/m/is_a', '/m/low'),
#   ('/m/0fpj9pm', '/m/is_a', '/m/low'),
#   ('/m/01jqr_5', '/m/is_a', '/m/low'),
#   ('/m/0p3sf', '/m/is_a', '/m/high'),
#   ('/m/09qh1', '/m/is_a', '/m/low'),
#   ('/m/0m76b', '/m/is_a', '/m/high'),
#   ('/m/01g257', '/m/is_a', '/m/low'),
#   ('/m/02p7xc', '/m/is_a', '/m/high'),
#   ('/m/02y0yt', '/m/is_a', '/m/low'),
#   ('/m/06gp3f', '/m/is_a', '/m/low'),
#   ('/m/025jj7', '/m/is_a', '/m/low'),
#   ('/m/01wqpnm', '/m/is_a', '/m/high'),
#   ('/m/02_01w', '/m/is_a', '/m/high'),
#   ('/m/05np2', '/m/is_a', '/m/low'),
#   ('/m/05nn4k', '/m/is_a', '/m/low'),
#   ('/m/016ggh', '/m/is_a', '/m/low'),
#   ('/m/06g2d1', '/m/is_a', '/m/low'),
#   ('/m/02vtnf', '/m/is_a', '/m/high'),
#   ('/m/03h_0_z', '/m/is_a', '/m/low'),
#   ('/m/02ql_ms', '/m/is_a', '/m/high'),
#   ('/m/04wp2p', '/m/is_a', '/m/low'),
#   ('/m/0dx_q', '/m/is_a', '/m/high'),
#   ('/m/045hz5', '/m/is_a', '/m/low'),
#   ('/m/06msq2', '/m/is_a', '/m/high'),
#   ('/m/01whg97', '/m/is_a', '/m/low'),
#   ('/m/01cbt3', '/m/is_a', '/m/low'),
#   ('/m/07r1h', '/m/is_a', '/m/high'),
#   ('/m/023p29', '/m/is_a', '/m/low'),
#   ('/m/06jzh', '/m/is_a', '/m/low'),
#   ('/m/0lpjn', '/m/is_a', '/m/low'),
#   ('/m/0h7dd', '/m/is_a', '/m/high'),
#   ('/m/0prfz', '/m/is_a', '/m/low'),
#   ('/m/01w5jwb', '/m/is_a', '/m/high'),
#   ('/m/06pwf6', '/m/is_a', '/m/low'),
#   ('/m/02qvhbb', '/m/is_a', '/m/high'),
#   ('/m/03d63lb', '/m/is_a', '/m/low'),
#   ('/m/0q59y', '/m/is_a', '/m/low'),
#   ('/m/02znwv', '/m/is_a', '/m/low'),
#   ('/m/0627zr', '/m/is_a', '/m/low'),
#   ('/m/0d1_f', '/m/is_a', '/m/high'),
#   ('/m/03_bcg', '/m/is_a', '/m/low'),
#   ('/m/079kdz', '/m/is_a', '/m/low'),
#   ('/m/01v9724', '/m/is_a', '/m/low'),
#   ('/m/0pj9t', '/m/is_a', '/m/low'),
#   ('/m/03j3pg9', '/m/is_a', '/m/high'),
#   ('/m/0p9qb', '/m/is_a', '/m/high'),
#   ('/m/05b4rcb', '/m/is_a', '/m/low'),
#   ('/m/01qgry', '/m/is_a', '/m/low'),
#   ('/m/01wyq0w', '/m/is_a', '/m/low'),
#   ('/m/0bl60p', '/m/is_a', '/m/high'),
#   ('/m/0c31_', '/m/is_a', '/m/low'),
#   ('/m/03d9v8', '/m/is_a', '/m/low'),
#   ('/m/04_1nk', '/m/is_a', '/m/low'),
#   ('/m/02g40r', '/m/is_a', '/m/low'),
#   ('/m/03975z', '/m/is_a', '/m/low'),
#   ('/m/0829rj', '/m/is_a', '/m/high'),
#   ('/m/01pr_j6', '/m/is_a', '/m/low'),
#   ('/m/06g4l', '/m/is_a', '/m/low'),
#   ('/m/0fv6dr', '/m/is_a', '/m/high'),
#   ('/m/02lfwp', '/m/is_a', '/m/low'),
#   ('/m/03ywyk', '/m/is_a', '/m/high'),
#   ('/m/01nhkxp', '/m/is_a', '/m/high'),
#   ('/m/01rnxn', '/m/is_a', '/m/high'),
#   ('/m/01k3qj', '/m/is_a', '/m/high'),
#   ('/m/01wbgdv', '/m/is_a', '/m/low'),
#   ('/m/0137g1', '/m/is_a', '/m/high'),
#   ('/m/05qhnq', '/m/is_a', '/m/low'),
#   ('/m/01ps2h8', '/m/is_a', '/m/low'),
#   ('/m/02lfl4', '/m/is_a', '/m/low'),
#   ('/m/0qdwr', '/m/is_a', '/m/low'),
#   ('/m/01s7z0', '/m/is_a', '/m/low'),
#   ('/m/01j5x6', '/m/is_a', '/m/low'),
#   ('/m/0pj8m', '/m/is_a', '/m/high'),
#   ('/m/0161c2', '/m/is_a', '/m/high'),
#   ('/m/05dxl_', '/m/is_a', '/m/low'),
#   ('/m/02l0xc', '/m/is_a', '/m/high'),
#   ('/m/0gjcy', '/m/is_a', '/m/high'),
#   ('/m/0drc1', '/m/is_a', '/m/low'),
#   ('/m/0bqvs2', '/m/is_a', '/m/high'),
#   ('/m/05qsxy', '/m/is_a', '/m/high'),
#   ('/m/09dvgb8', '/m/is_a', '/m/low'),
#   ('/m/01vsy95', '/m/is_a', '/m/low'),
#   ('/m/04cr6qv', '/m/is_a', '/m/high'),
#   ('/m/019l68', '/m/is_a', '/m/high'),
#   ('/m/083wr9', '/m/is_a', '/m/high'),
#   ('/m/06688p', '/m/is_a', '/m/high'),
#   ('/m/096hm', '/m/is_a', '/m/high'),
#   ('/m/0psss', '/m/is_a', '/m/high'),
#   ('/m/02779r4', '/m/is_a', '/m/low'),
#   ('/m/015cbq', '/m/is_a', '/m/low'),
#   ('/m/04wvhz', '/m/is_a', '/m/low'),
#   ('/m/01wp_jm', '/m/is_a', '/m/high'),
#   ('/m/016s_5', '/m/is_a', '/m/high'),
#   ('/m/01my_c', '/m/is_a', '/m/high'),
#   ('/m/07jmgz', '/m/is_a', '/m/low'),
#   ('/m/01x1fq', '/m/is_a', '/m/high'),
#   ('/m/0fz27v', '/m/is_a', '/m/high'),
#   ('/m/015p3p', '/m/is_a', '/m/high'),
#   ('/m/06t8b', '/m/is_a', '/m/high'),
#   ('/m/07f3xb', '/m/is_a', '/m/high'),
#   ('/m/05zh9c', '/m/is_a', '/m/high'),
#   ('/m/032nwy', '/m/is_a', '/m/high'),
#   ('/m/01cwkq', '/m/is_a', '/m/low'),
#   ('/m/03772', '/m/is_a', '/m/low'),
#   ('/m/03f0fnk', '/m/is_a', '/m/low'),
#   ('/m/0c_md_', '/m/is_a', '/m/low'),
#   ('/m/01vt5c_', '/m/is_a', '/m/high'),
#   ('/m/07lz9l', '/m/is_a', '/m/high'),
#   ('/m/0l12d', '/m/is_a', '/m/low'),
#   ('/m/01wbz9', '/m/is_a', '/m/high'),
#   ('/m/01rcmg', '/m/is_a', '/m/low'),
#   ('/m/0646qh', '/m/is_a', '/m/low'),
#   ('/m/01wj9y9', '/m/is_a', '/m/high'),
#   ('/m/014dm6', '/m/is_a', '/m/low'),
#   ('/m/01c5d5', '/m/is_a', '/m/low'),
#   ('/m/01bpc9', '/m/is_a', '/m/high'),
#   ('/m/041jlr', '/m/is_a', '/m/high'),
#   ('/m/0m6x4', '/m/is_a', '/m/high'),
#   ('/m/02238b', '/m/is_a', '/m/high'),
#   ('/m/09bg4l', '/m/is_a', '/m/high'),
#   ('/m/057d89', '/m/is_a', '/m/high'),
#   ('/m/0cpjgj', '/m/is_a', '/m/high'),
#   ('/m/0dt1cm', '/m/is_a', '/m/high'),
#   ('/m/02xyl', '/m/is_a', '/m/high'),
#   ('/m/02h9_l', '/m/is_a', '/m/low'),
#   ('/m/09g0h', '/m/is_a', '/m/high'),
#   ('/m/0806vbn', '/m/is_a', '/m/low'),
#   ('/m/07cn2c', '/m/is_a', '/m/low'),
#   ('/m/02vg0', '/m/is_a', '/m/low'),
#   ('/m/0gr36', '/m/is_a', '/m/low'),
#   ('/m/04ktcgn', '/m/is_a', '/m/high'),
#   ('/m/01gw4f', '/m/is_a', '/m/high'),
#   ('/m/015gw6', '/m/is_a', '/m/low'),
#   ('/m/01qrbf', '/m/is_a', '/m/low'),
#   ('/m/04bcb1', '/m/is_a', '/m/low'),
#   ('/m/015v3r', '/m/is_a', '/m/low'),
#   ('/m/080r3', '/m/is_a', '/m/high'),
#   ('/m/04gr35', '/m/is_a', '/m/high'),
#   ('/m/029k55', '/m/is_a', '/m/high'),
#   ('/m/0hz_1', '/m/is_a', '/m/high'),
#   ('/m/01p47r', '/m/is_a', '/m/low'),
#   ('/m/062hgx', '/m/is_a', '/m/low'),
#   ('/m/043tg', '/m/is_a', '/m/high'),
#   ('/m/01wn718', '/m/is_a', '/m/low'),
#   ('/m/02s529', '/m/is_a', '/m/low'),
#   ('/m/036hf4', '/m/is_a', '/m/high'),
#   ('/m/0884hk', '/m/is_a', '/m/high'),
#   ('/m/01g23m', '/m/is_a', '/m/low'),
#   ('/m/02x_h0', '/m/is_a', '/m/high'),
#   ('/m/05b__vr', '/m/is_a', '/m/high'),
#   ('/m/01xsbh', '/m/is_a', '/m/high'),
#   ('/m/0pk41', '/m/is_a', '/m/high'),
#   ('/m/01t110', '/m/is_a', '/m/high'),
#   ('/m/0pkr1', '/m/is_a', '/m/low'),
#   ('/m/018p4y', '/m/is_a', '/m/low'),
#   ('/m/0ky1', '/m/is_a', '/m/high'),
#   ('/m/01yd8v', '/m/is_a', '/m/high'),
#   ('/m/014cw2', '/m/is_a', '/m/low'),
#   ('/m/01vtqml', '/m/is_a', '/m/high'),
#   ('/m/0pmhf', '/m/is_a', '/m/low'),
#   ('/m/01m7pwq', '/m/is_a', '/m/high'),
#   ('/m/0cf_h9', '/m/is_a', '/m/high'),
#   ('/m/01vrlr4', '/m/is_a', '/m/high'),
#   ('/m/02zfdp', '/m/is_a', '/m/low'),
#   ('/m/0mj1l', '/m/is_a', '/m/high'),
#   ('/m/02p65p', '/m/is_a', '/m/low'),
#   ('/m/07w21', '/m/is_a', '/m/low'),
#   ('/m/0135xb', '/m/is_a', '/m/high'),
#   ('/m/02jsgf', '/m/is_a', '/m/low'),
#   ('/m/01wd3l', '/m/is_a', '/m/high'),
#   ('/m/03f1d47', '/m/is_a', '/m/low'),
#   ('/m/09r1j5', '/m/is_a', '/m/high'),
#   ('/m/05yjhm', '/m/is_a', '/m/high'),
#   ('/m/01364q', '/m/is_a', '/m/high'),
#   ('/m/022411', '/m/is_a', '/m/low'),
#   ('/m/03gm48', '/m/is_a', '/m/low'),
#   ('/m/01xwv7', '/m/is_a', '/m/low'),
#   ('/m/0gct_', '/m/is_a', '/m/high'),
#   ('/m/01hkck', '/m/is_a', '/m/high'),
#   ('/m/09y20', '/m/is_a', '/m/high'),
#   ('/m/0dt645q', '/m/is_a', '/m/high'),
#   ('/m/018x3', '/m/is_a', '/m/low'),
#   ('/m/045g4l', '/m/is_a', '/m/high'),
#   ('/m/08qmfm', '/m/is_a', '/m/low'),
#   ('/m/03cn92', '/m/is_a', '/m/high'),
#   ('/m/03pm9', '/m/is_a', '/m/high'),
#   ('/m/0d0mbj', '/m/is_a', '/m/high'),
#   ('/m/0f8pz', '/m/is_a', '/m/low'),
#   ('/m/0ffgh', '/m/is_a', '/m/high'),
#   ('/m/01v3vp', '/m/is_a', '/m/high'),
#   ('/m/0h336', '/m/is_a', '/m/low'),
#   ('/m/016yr0', '/m/is_a', '/m/low'),
#   ('/m/04yyhw', '/m/is_a', '/m/high'),
#   ('/m/03jm6c', '/m/is_a', '/m/high'),
#   ('/m/014kg4', '/m/is_a', '/m/low'),
#   ('/m/051x52f', '/m/is_a', '/m/low'),
#   ('/m/03f1zhf', '/m/is_a', '/m/low'),
#   ('/m/0drdv', '/m/is_a', '/m/high'),
#   ('/m/082xp', '/m/is_a', '/m/low'),
#   ('/m/01nr36', '/m/is_a', '/m/high'),
#   ('/m/07fzq3', '/m/is_a', '/m/low'),
#   ('/m/01l3j', '/m/is_a', '/m/high'),
#   ('/m/0phx4', '/m/is_a', '/m/high'),
#   ('/m/02yygk', '/m/is_a', '/m/low'),
#   ('/m/0dqmt0', '/m/is_a', '/m/high'),
#   ('/m/0207wx', '/m/is_a', '/m/low'),
#   ('/m/0c4qzm', '/m/is_a', '/m/high'),
#   ('/m/040wdl', '/m/is_a', '/m/low'),
#   ('/m/0168dy', '/m/is_a', '/m/high'),
#   ('/m/03clrng', '/m/is_a', '/m/low'),
#   ('/m/01_k1z', '/m/is_a', '/m/low'),
#   ('/m/09_99w', '/m/is_a', '/m/high'),
#   ('/m/01mt1fy', '/m/is_a', '/m/low'),
#   ('/m/085gk', '/m/is_a', '/m/high'),
#   ('/m/03cp7b3', '/m/is_a', '/m/high'),
#   ('/m/07hhnl', '/m/is_a', '/m/high'),
#   ('/m/02qnk5c', '/m/is_a', '/m/high'),
#   ('/m/0835q', '/m/is_a', '/m/low'),
#   ('/m/02sj1x', '/m/is_a', '/m/high'),
#   ('/m/01wk51', '/m/is_a', '/m/low'),
#   ('/m/0jlv5', '/m/is_a', '/m/high'),
#   ('/m/025l5', '/m/is_a', '/m/low'),
#   ('/m/01cpqk', '/m/is_a', '/m/high'),
# ...
#   ('/m/01svw8n', '/m/is_a', '/m/low'),
#   ('/m/05typm', '/m/is_a', '/m/high'),
#   ('/m/07dnx', '/m/is_a', '/m/low'),
#   ('/m/015p37', '/m/is_a', '/m/high'),
#   ('/m/0ldd', '/m/is_a', '/m/low'),
#   ('/m/01l2fn', '/m/is_a', '/m/low'),
#   ('/m/03mdw3c', '/m/is_a', '/m/high'),
#   ('/m/049k07', '/m/is_a', '/m/low'),
#   ('/m/016sqs', '/m/is_a', '/m/low'),
#   ('/m/0bxtyq', '/m/is_a', '/m/high'),
#   ('/m/02wh0', '/m/is_a', '/m/high'),
#   ('/m/02gnlz', '/m/is_a', '/m/high'),
#   ('/m/0785v8', '/m/is_a', '/m/low'),
#   ('/m/01dvtx', '/m/is_a', '/m/high'),
#   ('/m/0c1pj', '/m/is_a', '/m/high'),
#   ('/m/0chrwb', '/m/is_a', '/m/low'),
#   ('/m/06_bq1', '/m/is_a', '/m/high'),
#   ('/m/0bs8d', '/m/is_a', '/m/high'),
#   ('/m/051cc', '/m/is_a', '/m/high'),
#   ('/m/0j3v', '/m/is_a', '/m/high'),
#   ('/m/02tkzn', '/m/is_a', '/m/high'),
#   ('/m/0b80__', '/m/is_a', '/m/low'),
#   ('/m/07yw6t', '/m/is_a', '/m/low'),
#   ('/m/0152cw', '/m/is_a', '/m/high'),
#   ('/m/0dgskx', '/m/is_a', '/m/high'),
#   ('/m/018fmr', '/m/is_a', '/m/high'),
#   ('/m/04crrxr', '/m/is_a', '/m/low'),
#   ('/m/09hd6f', '/m/is_a', '/m/low'),
#   ('/m/02m501', '/m/is_a', '/m/high'),
#   ('/m/0521d_3', '/m/is_a', '/m/low'),
#   ('/m/02v2jy', '/m/is_a', '/m/low'),
#   ('/m/07c37', '/m/is_a', '/m/high'),
#   ('/m/01mqnr', '/m/is_a', '/m/high'),
#   ('/m/02cpb7', '/m/is_a', '/m/low'),
#   ('/m/027y151', '/m/is_a', '/m/low'),
#   ('/m/01r7t9', '/m/is_a', '/m/low'),
#   ('/m/04w1j9', '/m/is_a', '/m/high'),
#   ('/m/02lyx4', '/m/is_a', '/m/low'),
#   ('/m/013v5j', '/m/is_a', '/m/high'),
#   ('/m/02p21g', '/m/is_a', '/m/high'),
#   ('/m/053y0s', '/m/is_a', '/m/high'),
#   ('/m/0412f5y', '/m/is_a', '/m/high'),
#   ('/m/043s3', '/m/is_a', '/m/high'),
#   ('/m/09v6gc9', '/m/is_a', '/m/low'),
#   ('/m/0261g5l', '/m/is_a', '/m/low'),
#   ('/m/01vs8ng', '/m/is_a', '/m/high'),
#   ('/m/0g9zjp', '/m/is_a', '/m/low'),
#   ('/m/015gsv', '/m/is_a', '/m/high'),
#   ('/m/02v92l', '/m/is_a', '/m/high'),
#   ('/m/05r5w', '/m/is_a', '/m/high'),
#   ('/m/0993r', '/m/is_a', '/m/low'),
#   ('/m/01vvyd8', '/m/is_a', '/m/low'),
#   ('/m/033jj1', '/m/is_a', '/m/low'),
#   ('/m/05hdf', '/m/is_a', '/m/high'),
#   ('/m/03f5vvx', '/m/is_a', '/m/high'),
#   ('/m/016fjj', '/m/is_a', '/m/low'),
#   ('/m/01vv6_6', '/m/is_a', '/m/low'),
#   ('/m/04k25', '/m/is_a', '/m/low'),
#   ('/m/011_3s', '/m/is_a', '/m/high'),
#   ('/m/05bnq3j', '/m/is_a', '/m/high'),
#   ('/m/09rp4r_', '/m/is_a', '/m/low'),
#   ('/m/01gvyp', '/m/is_a', '/m/low'),
#   ('/m/02pzck', '/m/is_a', '/m/high'),
#   ('/m/026dx', '/m/is_a', '/m/low'),
#   ('/m/034rd', '/m/is_a', '/m/high'),
#   ('/m/07s8hms', '/m/is_a', '/m/high'),
#   ('/m/04pp9s', '/m/is_a', '/m/low'),
#   ('/m/074tb5', '/m/is_a', '/m/high'),
#   ('/m/01p87y', '/m/is_a', '/m/high'),
#   ('/m/0zm1', '/m/is_a', '/m/high'),
#   ('/m/01n8gr', '/m/is_a', '/m/high'),
#   ('/m/03xnq9_', '/m/is_a', '/m/low'),
#   ('/m/04dz_y7', '/m/is_a', '/m/high'),
#   ('/m/01zh29', '/m/is_a', '/m/high'),
#   ('/m/04ls53', '/m/is_a', '/m/low'),
#   ('/m/03f68r6', '/m/is_a', '/m/low'),
#   ('/m/015k7', '/m/is_a', '/m/high'),
#   ('/m/02h8hr', '/m/is_a', '/m/high'),
#   ('/m/026r8q', '/m/is_a', '/m/high'),
#   ('/m/01tv3x2', '/m/is_a', '/m/high'),
#   ('/m/0flw6', '/m/is_a', '/m/low'),
#   ('/m/01507p', '/m/is_a', '/m/high'),
#   ('/m/022s1m', '/m/is_a', '/m/high'),
#   ('/m/0bx0lc', '/m/is_a', '/m/low'),
#   ('/m/04n7njg', '/m/is_a', '/m/high'),
#   ('/m/0frpd5', '/m/is_a', '/m/high'),
#   ('/m/01jfr3y', '/m/is_a', '/m/low'),
#   ('/m/01w8n89', '/m/is_a', '/m/low'),
#   ('/m/041mt', '/m/is_a', '/m/high'),
#   ('/m/0kp2_', '/m/is_a', '/m/high'),
#   ('/m/02rgz97', '/m/is_a', '/m/high'),
#   ('/m/04n2vgk', '/m/is_a', '/m/high'),
#   ('/m/07d3z7', '/m/is_a', '/m/high'),
#   ('/m/0h7pj', '/m/is_a', '/m/high'),
#   ('/m/06lgq8', '/m/is_a', '/m/high'),
#   ('/m/01f9zw', '/m/is_a', '/m/high'),
#   ('/m/04fcx7', '/m/is_a', '/m/high'),
#   ('/m/02qzjj', '/m/is_a', '/m/low'),
#   ('/m/0bvls5', '/m/is_a', '/m/high'),
#   ('/m/081t6', '/m/is_a', '/m/low'),
#   ('/m/02x8mt', '/m/is_a', '/m/high'),
#   ('/m/01yzhn', '/m/is_a', '/m/high'),
#   ('/m/0fmqp6', '/m/is_a', '/m/high'),
#   ('/m/08xz51', '/m/is_a', '/m/low'),
#   ('/m/0347db', '/m/is_a', '/m/high'),
#   ('/m/0mfj2', '/m/is_a', '/m/high'),
#   ('/m/03x22w', '/m/is_a', '/m/low'),
#   ('/m/02qnhk1', '/m/is_a', '/m/low'),
#   ('/m/07m69t', '/m/is_a', '/m/low'),
#   ('/m/01chc7', '/m/is_a', '/m/high'),
#   ('/m/01nglk', '/m/is_a', '/m/low'),
#   ('/m/0b7t3p', '/m/is_a', '/m/low'),
#   ('/m/0bn3jg', '/m/is_a', '/m/low'),
#   ('/m/013t9y', '/m/is_a', '/m/low'),
#   ('/m/0btj0', '/m/is_a', '/m/low'),
#   ('/m/0h96g', '/m/is_a', '/m/low'),
#   ('/m/02fbpz', '/m/is_a', '/m/high'),
#   ('/m/017149', '/m/is_a', '/m/high'),
#   ('/m/0cpvcd', '/m/is_a', '/m/high'),
#   ('/m/01rr9f', '/m/is_a', '/m/low'),
#   ('/m/05vzw3', '/m/is_a', '/m/high'),
#   ('/m/012wg', '/m/is_a', '/m/low'),
#   ('/m/01nz1q6', '/m/is_a', '/m/high'),
#   ('/m/02rf1y', '/m/is_a', '/m/low'),
#   ('/m/01tfck', '/m/is_a', '/m/low'),
#   ('/m/023jq1', '/m/is_a', '/m/low'),
#   ('/m/01tsbmv', '/m/is_a', '/m/low'),
#   ('/m/07ymr5', '/m/is_a', '/m/high'),
#   ('/m/02rxbmt', '/m/is_a', '/m/low'),
#   ('/m/01bpnd', '/m/is_a', '/m/low'),
#   ('/m/02rmxx', '/m/is_a', '/m/low'),
#   ('/m/0qdyf', '/m/is_a', '/m/high'),
#   ('/m/04s9n', '/m/is_a', '/m/high'),
#   ('/m/06mm1x', '/m/is_a', '/m/high'),
#   ('/m/02zjd', '/m/is_a', '/m/high'),
#   ('/m/05ggt_', '/m/is_a', '/m/high'),
#   ('/m/06whf', '/m/is_a', '/m/high'),
#   ('/m/09zmys', '/m/is_a', '/m/high'),
#   ('/m/0h1_w', '/m/is_a', '/m/high'),
#   ('/m/0klw', '/m/is_a', '/m/high'),
#   ('/m/0cg9f', '/m/is_a', '/m/low'),
#   ('/m/09dv0sz', '/m/is_a', '/m/low'),
#   ('/m/094wz7q', '/m/is_a', '/m/low'),
#   ('/m/019l3m', '/m/is_a', '/m/low'),
#   ('/m/01pcbg', '/m/is_a', '/m/low'),
#   ('/m/01x6v6', '/m/is_a', '/m/high'),
#   ('/m/0191h5', '/m/is_a', '/m/high'),
#   ('/m/02knnd', '/m/is_a', '/m/low'),
#   ('/m/01fxfk', '/m/is_a', '/m/low'),
#   ('/m/01mskc3', '/m/is_a', '/m/low'),
#   ('/m/04yqlk', '/m/is_a', '/m/low'),
#   ('/m/015z4j', '/m/is_a', '/m/high'),
#   ('/m/04_by', '/m/is_a', '/m/high'),
#   ('/m/02pjvc', '/m/is_a', '/m/high'),
#   ('/m/078jt5', '/m/is_a', '/m/high'),
#   ('/m/01lbp', '/m/is_a', '/m/high'),
#   ('/m/058z1hb', '/m/is_a', '/m/low'),
#   ('/m/02bn75', '/m/is_a', '/m/high'),
#   ('/m/02lxj_', '/m/is_a', '/m/low'),
#   ('/m/012j5h', '/m/is_a', '/m/low'),
#   ('/m/018dyl', '/m/is_a', '/m/low'),
#   ('/m/02rsz0', '/m/is_a', '/m/low'),
#   ('/m/033_1p', '/m/is_a', '/m/high'),
#   ('/m/0cmpn', '/m/is_a', '/m/high'),
#   ('/m/040dv', '/m/is_a', '/m/high'),
#   ('/m/078g3l', '/m/is_a', '/m/high'),
#   ('/m/01xv77', '/m/is_a', '/m/low'),
#   ('/m/0bs1yy', '/m/is_a', '/m/high'),
#   ('/m/042xrr', '/m/is_a', '/m/high'),
#   ('/m/0f5xn', '/m/is_a', '/m/low'),
#   ('/m/027f7dj', '/m/is_a', '/m/low'),
#   ('/m/01rnpy', '/m/is_a', '/m/low'),
#   ('/m/0c43g', '/m/is_a', '/m/low'),
#   ('/m/0mbw0', '/m/is_a', '/m/low'),
#   ('/m/05p92jn', '/m/is_a', '/m/high'),
#   ('/m/063_t', '/m/is_a', '/m/high'),
#   ('/m/04n7gc6', '/m/is_a', '/m/high'),
#   ('/m/0c7ct', '/m/is_a', '/m/low'),
#   ('/m/04t2l2', '/m/is_a', '/m/high'),
#   ('/m/01wjrn', '/m/is_a', '/m/high'),
#   ('/m/01mvpv', '/m/is_a', '/m/low'),
#   ('/m/03cs_xw', '/m/is_a', '/m/low'),
#   ('/m/07rzf', '/m/is_a', '/m/high'),
#   ('/m/01r4zfk', '/m/is_a', '/m/low'),
#   ('/m/07s9tsr', '/m/is_a', '/m/high'),
#   ('/m/01vvyc_', '/m/is_a', '/m/high'),
#   ('/m/01385g', '/m/is_a', '/m/low'),
#   ('/m/027rfxc', '/m/is_a', '/m/high'),
#   ('/m/0436f4', '/m/is_a', '/m/high'),
#   ('/m/05f0r8', '/m/is_a', '/m/low'),
#   ('/m/01wskg', '/m/is_a', '/m/high'),
#   ('/m/01k_mc', '/m/is_a', '/m/low'),
#   ('/m/02n9k', '/m/is_a', '/m/high'),
#   ('/m/05cljf', '/m/is_a', '/m/high'),
#   ('/m/08qvhv', '/m/is_a', '/m/low'),
#   ('/m/04gtdnh', '/m/is_a', '/m/low'),
#   ('/m/01wbl_r', '/m/is_a', '/m/low'),
#   ('/m/0143wl', '/m/is_a', '/m/low'),
#   ('/m/05d8vw', '/m/is_a', '/m/high'),
#   ('/m/070w7s', '/m/is_a', '/m/low'),
#   ('/m/015grj', '/m/is_a', '/m/low'),
#   ('/m/0c2dl', '/m/is_a', '/m/low'),
#   ('/m/0b82vw', '/m/is_a', '/m/high'),
#   ('/m/06sy4c', '/m/is_a', '/m/high'),
#   ('/m/0g2lq', '/m/is_a', '/m/low'),
#   ('/m/014zfs', '/m/is_a', '/m/high'),
#   ('/m/0854hr', '/m/is_a', '/m/high'),
#   ('/m/03h304l', '/m/is_a', '/m/low'),
#   ('/m/01t94_1', '/m/is_a', '/m/high'),
#   ('/m/05fg2', '/m/is_a', '/m/high'),
#   ('/m/0mj0c', '/m/is_a', '/m/low'),
#   ('/m/0gkydb', '/m/is_a', '/m/low'),
#   ('/m/028d4v', '/m/is_a', '/m/low'),
#   ('/m/01tz6vs', '/m/is_a', '/m/low'),
#   ('/m/0641g8', '/m/is_a', '/m/low'),
#   ('/m/0134w7', '/m/is_a', '/m/high'),
#   ('/m/03yf3z', '/m/is_a', '/m/low'),
#   ('/m/0g7vxv', '/m/is_a', '/m/low'),
#   ('/m/01vsy9_', '/m/is_a', '/m/low'),
#   ('/m/03f0vvr', '/m/is_a', '/m/low'),
#   ('/m/049m19', '/m/is_a', '/m/low'),
#   ('/m/0p5mw', '/m/is_a', '/m/high'),
#   ('/m/02v3yy', '/m/is_a', '/m/high'),
#   ('/m/03cxsvl', '/m/is_a', '/m/high'),
#   ('/m/0127xk', '/m/is_a', '/m/low'),
#   ('/m/03kcyd', '/m/is_a', '/m/low'),
#   ('/m/025_nbr', '/m/is_a', '/m/low'),
#   ('/m/03cfjg', '/m/is_a', '/m/high'),
#   ('/m/0149xx', '/m/is_a', '/m/low'),
#   ('/m/06kbb6', '/m/is_a', '/m/high'),
#   ('/m/01hkg9', '/m/is_a', '/m/high'),
#   ('/m/048tgl', '/m/is_a', '/m/low'),
#   ('/m/016gr2', '/m/is_a', '/m/low'),
#   ('/m/03csqj4', '/m/is_a', '/m/high'),
#   ('/m/04cmrt', '/m/is_a', '/m/low'),
#   ('/m/01w272y', '/m/is_a', '/m/high'),
#   ('/m/01rmnp', '/m/is_a', '/m/low'),
#   ('/m/03h40_7', '/m/is_a', '/m/high'),
#   ('/m/02k6rq', '/m/is_a', '/m/low'),
#   ('/m/01x4sb', '/m/is_a', '/m/high'),
#   ('/m/03fghg', '/m/is_a', '/m/high'),
#   ('/m/01jgpsh', '/m/is_a', '/m/high'),
#   ('/m/018dnt', '/m/is_a', '/m/low'),
#   ('/m/01nczg', '/m/is_a', '/m/low'),
#   ('/m/03qd_', '/m/is_a', '/m/low'),
#   ('/m/0g28b1', '/m/is_a', '/m/low'),
#   ('/m/058kqy', '/m/is_a', '/m/high'),
#   ('/m/07nx9j', '/m/is_a', '/m/high'),
#   ('/m/07y8l9', '/m/is_a', '/m/high'),
#   ('/m/08z39v', '/m/is_a', '/m/low'),
#   ('/m/02_t2t', '/m/is_a', '/m/low'),
#   ('/m/01_xtx', '/m/is_a', '/m/low'),
#   ('/m/02dlfh', '/m/is_a', '/m/high'),
#   ('/m/09k2t1', '/m/is_a', '/m/high'),
#   ('/m/0mb5x', '/m/is_a', '/m/high'),
#   ('/m/071h5c', '/m/is_a', '/m/low'),
#   ('/m/012pd4', '/m/is_a', '/m/low'),
#   ('/m/02fgpf', '/m/is_a', '/m/high'),
#   ('/m/05nw9m', '/m/is_a', '/m/low'),
#   ('/m/01c6l', '/m/is_a', '/m/high'),
#   ('/m/030dx5', '/m/is_a', '/m/high'),
#   ('/m/01mvth', '/m/is_a', '/m/high'),
#   ('/m/01vvdm', '/m/is_a', '/m/high'),
#   ('/m/02l4pj', '/m/is_a', '/m/high'),
#   ('/m/01trhmt', '/m/is_a', '/m/low'),
#   ('/m/01vs14j', '/m/is_a', '/m/high'),
#   ('/m/08t7nz', '/m/is_a', '/m/low'),
#   ('/m/01pbwwl', '/m/is_a', '/m/high'),
#   ('/m/09ld6g', '/m/is_a', '/m/low'),
#   ('/m/0g72r', '/m/is_a', '/m/high'),
#   ('/m/04rvy8', '/m/is_a', '/m/low'),
#   ('/m/0311wg', '/m/is_a', '/m/high'),
#   ('/m/03yrkt', '/m/is_a', '/m/high'),
#   ('/m/015nvj', '/m/is_a', '/m/high'),
#   ('/m/058w5', '/m/is_a', '/m/high'),
#   ('/m/030tjk', '/m/is_a', '/m/low'),
#   ('/m/04511f', '/m/is_a', '/m/low'),
#   ('/m/026ps1', '/m/is_a', '/m/low'),
#   ('/m/01wmjkb', '/m/is_a', '/m/low'),
#   ('/m/01t265', '/m/is_a', '/m/high'),
#   ('/m/03qncl3', '/m/is_a', '/m/low'),
#   ('/m/02zrv7', '/m/is_a', '/m/low'),
#   ('/m/0bn8fw', '/m/is_a', '/m/high'),
#   ('/m/05vsxz', '/m/is_a', '/m/low'),
#   ('/m/0265v21', '/m/is_a', '/m/high'),
#   ('/m/09pl3f', '/m/is_a', '/m/high'),
#   ('/m/01wk7b7', '/m/is_a', '/m/low'),
#   ('/m/0278x6s', '/m/is_a', '/m/low'),
#   ('/m/079dy', '/m/is_a', '/m/high'),
#   ('/m/08f3yq', '/m/is_a', '/m/low'),
#   ('/m/01pcql', '/m/is_a', '/m/low'),
#   ('/m/01w9ph_', '/m/is_a', '/m/high'),
#   ('/m/0794g', '/m/is_a', '/m/high'),
#   ('/m/07swvb', '/m/is_a', '/m/low'),
#   ('/m/082db', '/m/is_a', '/m/low'),
#   ('/m/05ccxr', '/m/is_a', '/m/high'),
#   ('/m/046qq', '/m/is_a', '/m/low'),
#   ('/m/02gn9g', '/m/is_a', '/m/high'),
#   ('/m/032nl2', '/m/is_a', '/m/low'),
#   ('/m/0m0nq', '/m/is_a', '/m/low'),
#   ('/m/06tp4h', '/m/is_a', '/m/high'),
#   ('/m/015rkw', '/m/is_a', '/m/low'),
#   ('/m/0bx_q', '/m/is_a', '/m/low'),
#   ('/m/03zrp', '/m/is_a', '/m/high'),
#   ('/m/06wvfq', '/m/is_a', '/m/low'),
#   ('/m/01pg1d', '/m/is_a', '/m/low'),
#   ('/m/027r0_f', '/m/is_a', '/m/high'),
#   ('/m/01gq0b', '/m/is_a', '/m/high'),
#   ('/m/090gpr', '/m/is_a', '/m/low'),
#   ('/m/0h1q6', '/m/is_a', '/m/low'),
#   ('/m/02t0n9', '/m/is_a', '/m/high'),
#   ('/m/028rk', '/m/is_a', '/m/low'),
#   ('/m/04135', '/m/is_a', '/m/low'),
#   ('/m/024swd', '/m/is_a', '/m/low'),
#   ('/m/049fgvm', '/m/is_a', '/m/low'),
#   ('/m/06b0d2', '/m/is_a', '/m/high'),
#   ('/m/04gvt5', '/m/is_a', '/m/low'),
#   ('/m/016dp0', '/m/is_a', '/m/low'),
#   ('/m/063g7l', '/m/is_a', '/m/low'),
#   ('/m/015q43', '/m/is_a', '/m/high'),
#   ('/m/030vnj', '/m/is_a', '/m/low'),
#   ('/m/05s_c38', '/m/is_a', '/m/low'),
#   ('/m/025cn2', '/m/is_a', '/m/high'),
#   ('/m/0202p_', '/m/is_a', '/m/high'),
#   ('/m/02w9895', '/m/is_a', '/m/low'),
#   ('/m/015gjr', '/m/is_a', '/m/low'),
#   ('/m/0czmk1', '/m/is_a', '/m/high'),
#   ('/m/01wd9vs', '/m/is_a', '/m/high'),
#   ('/m/0gdhhy', '/m/is_a', '/m/high'),
#   ('/m/0blq0z', '/m/is_a', '/m/low'),
#   ('/m/07ddz9', '/m/is_a', '/m/high'),
#   ('/m/0bz60q', '/m/is_a', '/m/high'),
#   ('/m/026sb55', '/m/is_a', '/m/low'),
#   ('/m/01rw116', '/m/is_a', '/m/high'),
#   ('/m/07_m9_', '/m/is_a', '/m/high'),
#   ('/m/06ltr', '/m/is_a', '/m/low'),
#   ('/m/02lvtb', '/m/is_a', '/m/high'),
#   ('/m/02wk4d', '/m/is_a', '/m/low'),
#   ('/m/0171cm', '/m/is_a', '/m/low'),
#   ('/m/0b6yp2', '/m/is_a', '/m/low'),
#   ('/m/01r2c7', '/m/is_a', '/m/high'),
#   ('/m/01vng3b', '/m/is_a', '/m/high'),
#   ('/m/01yznp', '/m/is_a', '/m/high'),
#   ('/m/0g_92', '/m/is_a', '/m/low'),
#   ('/m/02g0mx', '/m/is_a', '/m/low'),
#   ('/m/095x_', '/m/is_a', '/m/low'),
#   ('/m/0gs5q', '/m/is_a', '/m/high'),
#   ('/m/065d1h', '/m/is_a', '/m/low'),
#   ('/m/0kxbc', '/m/is_a', '/m/low'),
#   ('/m/03fvqg', '/m/is_a', '/m/low'),
#   ('/m/0lzcs', '/m/is_a', '/m/low'),
#   ('/m/03cz9_', '/m/is_a', '/m/low'),
#   ('/m/03cz4j', '/m/is_a', '/m/low'),
#   ('/m/02bfxb', '/m/is_a', '/m/high'),
#   ('/m/0863x_', '/m/is_a', '/m/low'),
#   ('/m/0h1nt', '/m/is_a', '/m/high'),
#   ('/m/04dqdk', '/m/is_a', '/m/high'),
#   ('/m/0kn3g', '/m/is_a', '/m/low'),
#   ('/m/05szp', '/m/is_a', '/m/high'),
#   ('/m/01jb26', '/m/is_a', '/m/high'),
#   ('/m/05218gr', '/m/is_a', '/m/high'),
#   ('/m/0ct9_', '/m/is_a', '/m/low'),
#   ('/m/011s9r', '/m/is_a', '/m/high'),
#   ('/m/03txms', '/m/is_a', '/m/low'),
#   ('/m/05pzdk', '/m/is_a', '/m/low'),
#   ('/m/0jdhp', '/m/is_a', '/m/low'),
#   ('/m/02fgp0', '/m/is_a', '/m/high'),
#   ('/m/07g2v', '/m/is_a', '/m/high'),
#   ('/m/03_0p', '/m/is_a', '/m/high'),
#   ('/m/0652ty', '/m/is_a', '/m/high'),
#   ('/m/0226cw', '/m/is_a', '/m/low'),
#   ('/m/052h3', '/m/is_a', '/m/low'),
#   ('/m/02kz_', '/m/is_a', '/m/high'),
#   ('/m/0fb1q', '/m/is_a', '/m/high'),
#   ('/m/012rng', '/m/is_a', '/m/low'),
#   ('/m/02r99xw', '/m/is_a', '/m/low'),
#   ('/m/01x0sy', '/m/is_a', '/m/high'),
#   ('/m/04j5fx', '/m/is_a', '/m/low'),
#   ('/m/017vkx', '/m/is_a', '/m/low'),
#   ('/m/016dgz', '/m/is_a', '/m/low'),
#   ('/m/02r3cn', '/m/is_a', '/m/high'),
#   ('/m/09bx1k', '/m/is_a', '/m/high'),
#   ('/m/01wg6y', '/m/is_a', '/m/high'),
#   ('/m/0159h6', '/m/is_a', '/m/low'),
#   ('/m/01cqz5', '/m/is_a', '/m/high'),
#   ('/m/02pbrn', '/m/is_a', '/m/high'),
#   ('/m/01vw_dv', '/m/is_a', '/m/high'),
#   ('/m/045cq', '/m/is_a', '/m/low'),
#   ('/m/0gv2r', '/m/is_a', '/m/low'),
#   ('/m/023kzp', '/m/is_a', '/m/low'),
#   ('/m/03y9ccy', '/m/is_a', '/m/high'),
#   ('/m/01wv9p', '/m/is_a', '/m/high'),
#   ('/m/015_30', '/m/is_a', '/m/high'),
#   ('/m/02fb1n', '/m/is_a', '/m/low'),
#   ('/m/04rs03', '/m/is_a', '/m/high'),
#   ('/m/0444x', '/m/is_a', '/m/high'),
#   ('/m/05fyss', '/m/is_a', '/m/low'),
#   ('/m/016xh5', '/m/is_a', '/m/high'),
#   ('/m/019vgs', '/m/is_a', '/m/low'),
#   ('/m/02ryx0', '/m/is_a', '/m/high'),
#   ('/m/05bpg3', '/m/is_a', '/m/high'),
#   ('/m/026v437', '/m/is_a', '/m/high'),
#   ('/m/015rhv', '/m/is_a', '/m/high'),
#   ('/m/03y82t6', '/m/is_a', '/m/low'),
#   ('/m/04w391', '/m/is_a', '/m/low'),
#   ('/m/0gv40', '/m/is_a', '/m/high'),
#   ('/m/03xds', '/m/is_a', '/m/high'),
#   ('/m/04fzk', '/m/is_a', '/m/low'),
#   ('/m/01jpmpv', '/m/is_a', '/m/high'),
#   ('/m/0178rl', '/m/is_a', '/m/low'),
#   ('/m/09mq4m', '/m/is_a', '/m/low'),
#   ('/m/032l1', '/m/is_a', '/m/high'),
#   ('/m/01s7qqw', '/m/is_a', '/m/high'),
#   ('/m/014488', '/m/is_a', '/m/low'),
#   ('/m/01nrz4', '/m/is_a', '/m/high'),
#   ...]}

# %%
# dump literal triples to file
with open(f'data/{dataset_name}/literals/numerical_literals.txt', 'w') as f:
    for triple in attributive_triples:
        f.write("\t".join(triple) + "\n")

# %%
# dump relational train triples to file
with open(f'data/{dataset_name}/train_value.txt', 'w') as f:
    for triple in relational_triples['train']:
        f.write("\t".join(triple) + "\n")

# %%
# generate relational test triples
test_relational = []

# neg_samples are random non-human entities that should not be assigned to /m/low or /m/high
neg_samples = class_mapping_df[class_mapping_df["class_label"] != "human"]['dataset_entity'].unique().tolist()
random.shuffle(neg_samples)

# generate the /m/is_a triples for the relevant entities
# for the human entities, we are going to investigate if /m/low or /m/high is assigned correctly -> investigate literal understanding
# for the non-human entities, we are going to investigate if /m/low or /m/high is not assigned as this never occurred in the training data -> investigate literal & structural understanding
for entity in uris_split['test'] + neg_samples[:675]:
    test_relational.append((entity, relational_relation, class_low))
    test_relational.append((entity, relational_relation, class_high))

# %%
# dump relational test triples to file
with open(f'data/{dataset_name}/test_value.txt', 'w') as f:
    for triple in test_relational:
        f.write("\t".join(triple) + "\n")

# %%
# add FB15k-237 triples to the dataset
for split in ['train', 'test', 'valid']:
    shutil.copyfile(f'./data/FB15k-237/{split}.txt', f'./data/{dataset_name}/{split}.txt')

for split in ['train', 'test']:
    with open(f'./data/{dataset_name}/{split}_value.txt') as train_value_file:
        with open(f'./data/{dataset_name}/{split}.txt', 'a') as train_file:
            train_file.write(train_value_file.read())
